# %%
# general python libraries
import re
from tabulate import tabulate
from pandas.core.dtypes.missing import isnull
import time
import calendar

# import API library
# !pip install pandas googlemaps
import googlemaps

# database and numeric libraries
import pandas as pd
import numpy as np

#visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import matplotlib.dates as mdates

#Display all the columns and rows
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# command to ignore warnings during filtering
import warnings
warnings.filterwarnings('ignore')
# Out:
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (2.1.4)
# Collecting googlemaps
#   Downloading googlemaps-4.10.0.tar.gz (33 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\programdata\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: requests<3.0,>=2.20.0 in c:\programdata\anaconda3\lib\site-packages (from googlemaps) (2.31.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2024.2.2)
# Building wheels for collected packages: googlemaps
#   Building wheel for googlemaps (setup.py): started
#   Building wheel for googlemaps (setup.py): finished with status 'done'
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40746 sha256=29bbebc8b08b149e95689d6d7618560e40f08a252fd1a2e4976c7cbe85619990
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\f1\09\77\3cc2f5659cbc62341b30f806aca2b25e6a26c351daa5b1f49a
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.10.0

# %%
df=pd.read_csv('Crime_20250211.csv')
df.head()
# Out:
#    Incident ID Offence Code  CR Number    Dispatch Date / Time  \
# 0    201166610         2308  170548599                     NaN
# 1    201359823         5404  220000965  01/09/2022 01:18:38 AM
# 2    201095140         2303   16043118                     NaN
# 3    201090710         5707   16037677                     NaN
# 4    201362142         2901  220003839  01/28/2022 07:11:29 PM
#
#           Start_Date_Time           End_Date_Time NIBRS Code  Victims  \
# 0  12/14/2017 04:30:00 PM                     NaN        23D        1
# 1  01/09/2022 01:34:00 AM                     NaN        90D        1
# 2  08/24/2016 09:47:00 PM                     NaN        23C        1
# 3  07/25/2016 05:31:00 PM                     NaN        90J        1
# 4  01/28/2022 02:40:00 PM  01/28/2022 02:46:00 PM        290        1
#
#               Crime Name1                               Crime Name2  \
# 0  Crime Against Property                       Theft from Building
# 1   Crime Against Society               Driving Under the Influence
# 2  Crime Against Property                               Shoplifting
# 3   Crime Against Society                 Trespass of Real Property
# 4  Crime Against Property  Destruction/Damage/Vandalism of Property
#
#                           Crime Name3 Police District Name  \
# 0                 LARCENY - FROM BLDG            ROCKVILLE
# 1  DRIVING UNDER THE INFLUENCE LIQUOR   MONTGOMERY VILLAGE
# 2               LARCENY - SHOPLIFTING            ROCKVILLE
# 3                         TRESPASSING              WHEATON
# 4          DAMAGE PROPERTY - BUSINESS   MONTGOMERY VILLAGE
#
#                Block Address           City State  Zip Code Agency  \
# 0    1700 BLK E JEFFERSON ST      ROCKVILLE    MD   20852.0   MCPD
# 1    100 BLK N FREDERICK AVE   GAITHERSBURG    MD   20877.0    GPD
# 2          5700 BLK  BOU AVE      ROCKVILLE    MD   20852.0   MCPD
# 3   11100 BLK  VEIRS MILL RD  SILVER SPRING    MD   20902.0   MCPD
# 4  18500 BLK N FREDERICK AVE   GAITHERSBURG    MD   20879.0    GPD
#
#                              Place Sector Beat  PRA  Address Number  \
# 0  Retail - Appliances/Electronics      A  1A1  270          1700.0
# 1              Street - In vehicle      P  6P2  428           100.0
# 2                Retail - Clothing      A  1A2  271          5700.0
# 3                    Retail - Mall      L  4L2  321         11100.0
# 4                   Retail - Other      R  6R2  545         18500.0
#
#   Street Prefix Street Name Street Suffix Street Type  Latitude  Longitude  \
# 0             E   JEFFERSON           NaN          ST  39.05848   -77.1264
# 1             N   FREDERICK           NaN         AVE  39.09438   -77.1517
# 2           NaN         BOU           NaN         AVE  39.05597   -77.1136
# 3           NaN  VEIRS MILL           NaN          RD  39.03758   -77.0519
# 4             N   FREDERICK           NaN         AVE  39.16059   -77.2209
#
#   Police District Number             Location
# 0                     1D  (39.0585, -77.1264)
# 1                     6D  (39.0944, -77.1517)
# 2                     1D   (39.056, -77.1136)
# 3                     4D  (39.0376, -77.0519)
# 4                     6D  (39.1606, -77.2209)

# %%
# Number of the rows and columns
df.shape
# Out:
# (432139, 30)

# %%
# List of all the columns
df.columns
# Out:
# Index(['Incident ID', 'Offence Code', 'CR Number', 'Dispatch Date / Time',
#        'Start_Date_Time', 'End_Date_Time', 'NIBRS Code', 'Victims',
#        'Crime Name1', 'Crime Name2', 'Crime Name3', 'Police District Name',
#        'Block Address', 'City', 'State', 'Zip Code', 'Agency', 'Place',
#        'Sector', 'Beat', 'PRA', 'Address Number', 'Street Prefix',
#        'Street Name', 'Street Suffix', 'Street Type', 'Latitude', 'Longitude',
#        'Police District Number', 'Location'],
#       dtype='object')

# %%
# Print a sample of the DataFrame
df.head(5)
# Out:
#    Incident ID Offence Code  CR Number    Dispatch Date / Time  \
# 0    201166610         2308  170548599                     NaN
# 1    201359823         5404  220000965  01/09/2022 01:18:38 AM
# 2    201095140         2303   16043118                     NaN
# 3    201090710         5707   16037677                     NaN
# 4    201362142         2901  220003839  01/28/2022 07:11:29 PM
#
#           Start_Date_Time           End_Date_Time NIBRS Code  Victims  \
# 0  12/14/2017 04:30:00 PM                     NaN        23D        1
# 1  01/09/2022 01:34:00 AM                     NaN        90D        1
# 2  08/24/2016 09:47:00 PM                     NaN        23C        1
# 3  07/25/2016 05:31:00 PM                     NaN        90J        1
# 4  01/28/2022 02:40:00 PM  01/28/2022 02:46:00 PM        290        1
#
#               Crime Name1                               Crime Name2  \
# 0  Crime Against Property                       Theft from Building
# 1   Crime Against Society               Driving Under the Influence
# 2  Crime Against Property                               Shoplifting
# 3   Crime Against Society                 Trespass of Real Property
# 4  Crime Against Property  Destruction/Damage/Vandalism of Property
#
#                           Crime Name3 Police District Name  \
# 0                 LARCENY - FROM BLDG            ROCKVILLE
# 1  DRIVING UNDER THE INFLUENCE LIQUOR   MONTGOMERY VILLAGE
# 2               LARCENY - SHOPLIFTING            ROCKVILLE
# 3                         TRESPASSING              WHEATON
# 4          DAMAGE PROPERTY - BUSINESS   MONTGOMERY VILLAGE
#
#                Block Address           City State  Zip Code Agency  \
# 0    1700 BLK E JEFFERSON ST      ROCKVILLE    MD   20852.0   MCPD
# 1    100 BLK N FREDERICK AVE   GAITHERSBURG    MD   20877.0    GPD
# 2          5700 BLK  BOU AVE      ROCKVILLE    MD   20852.0   MCPD
# 3   11100 BLK  VEIRS MILL RD  SILVER SPRING    MD   20902.0   MCPD
# 4  18500 BLK N FREDERICK AVE   GAITHERSBURG    MD   20879.0    GPD
#
#                              Place Sector Beat  PRA  Address Number  \
# 0  Retail - Appliances/Electronics      A  1A1  270          1700.0
# 1              Street - In vehicle      P  6P2  428           100.0
# 2                Retail - Clothing      A  1A2  271          5700.0
# 3                    Retail - Mall      L  4L2  321         11100.0
# 4                   Retail - Other      R  6R2  545         18500.0
#
#   Street Prefix Street Name Street Suffix Street Type  Latitude  Longitude  \
# 0             E   JEFFERSON           NaN          ST  39.05848   -77.1264
# 1             N   FREDERICK           NaN         AVE  39.09438   -77.1517
# 2           NaN         BOU           NaN         AVE  39.05597   -77.1136
# 3           NaN  VEIRS MILL           NaN          RD  39.03758   -77.0519
# 4             N   FREDERICK           NaN         AVE  39.16059   -77.2209
#
#   Police District Number             Location
# 0                     1D  (39.0585, -77.1264)
# 1                     6D  (39.0944, -77.1517)
# 2                     1D   (39.056, -77.1136)
# 3                     4D  (39.0376, -77.0519)
# 4                     6D  (39.1606, -77.2209)

# %%
# Print Data type and summary of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432139 entries, 0 to 432138
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Incident ID             432139 non-null  int64
#  1   Offence Code            432139 non-null  object
#  2   CR Number               432139 non-null  int64
#  3   Dispatch Date / Time    369661 non-null  object
#  4   Start_Date_Time         432139 non-null  object
#  5   End_Date_Time           197529 non-null  object
#  6   NIBRS Code              432139 non-null  object
#  7   Victims                 432139 non-null  int64
#  8   Crime Name1             432139 non-null  object
#  9   Crime Name2             432139 non-null  object
#  10  Crime Name3             432139 non-null  object
#  11  Police District Name    431076 non-null  object
#  12  Block Address           397305 non-null  object
#  13  City                    432124 non-null  object
#  14  State                   422643 non-null  object
#  15  Zip Code                428821 non-null  float64
#  16  Agency                  432139 non-null  object
#  17  Place                   432139 non-null  object
#  18  Sector                  432139 non-null  object
#  19  Beat                    432139 non-null  object
#  20  PRA                     432130 non-null  object
#  21  Address Number          397443 non-null  float64
#  22  Street Prefix           19641 non-null   object
#  23  Street Name             431075 non-null  object
#  24  Street Suffix           5931 non-null    object
#  25  Street Type             430691 non-null  object
#  26  Latitude                432139 non-null  float64
#  27  Longitude               432139 non-null  float64
#  28  Police District Number  432139 non-null  object
#  29  Location                432139 non-null  object
# dtypes: float64(4), int64(3), object(23)
# memory usage: 98.9+ MB

# %%
#Statistical summary of dataset
df.describe()
# Out:
#         Incident ID     CR Number        Victims       Zip Code  \
# count  4.321390e+05  4.321390e+05  432139.000000  428821.000000
# mean   2.012985e+08  1.876832e+08       1.021574   20876.853361
# std    1.226632e+05  5.987521e+07       0.183807     143.601519
# min    2.010871e+08  1.001107e+07       1.000000       6.000000
# 25%    2.011930e+08  1.800296e+08       1.000000   20853.000000
# 50%    2.012965e+08  2.000291e+08       1.000000   20878.000000
# 75%    2.014024e+08  2.200516e+08       1.000000   20904.000000
# max    2.015157e+08  2.500061e+08      22.000000   29882.000000
#
#        Address Number       Latitude      Longitude
# count    3.974430e+05  432139.000000  432139.000000
# mean     8.374239e+03      37.894631     -74.772489
# std      1.639290e+04       6.707403      13.234449
# min      0.000000e+00       0.000000     -77.516700
# 25%      1.500000e+03      39.020060     -77.197600
# 50%      8.100000e+03      39.072190     -77.098900
# 75%      1.240000e+04      39.141740     -77.028100
# max      2.090600e+06      39.351240       0.000000

# %%
# Drop the columns which are not required for our analysis
df = df.drop(['Incident ID','Latitude','Longitude'], axis=1)
df.head()
# Out:
#   Offence Code  CR Number    Dispatch Date / Time         Start_Date_Time  \
# 0         2308  170548599                     NaN  12/14/2017 04:30:00 PM
# 1         5404  220000965  01/09/2022 01:18:38 AM  01/09/2022 01:34:00 AM
# 2         2303   16043118                     NaN  08/24/2016 09:47:00 PM
# 3         5707   16037677                     NaN  07/25/2016 05:31:00 PM
# 4         2901  220003839  01/28/2022 07:11:29 PM  01/28/2022 02:40:00 PM
#
#             End_Date_Time NIBRS Code  Victims             Crime Name1  \
# 0                     NaN        23D        1  Crime Against Property
# 1                     NaN        90D        1   Crime Against Society
# 2                     NaN        23C        1  Crime Against Property
# 3                     NaN        90J        1   Crime Against Society
# 4  01/28/2022 02:46:00 PM        290        1  Crime Against Property
#
#                                 Crime Name2  \
# 0                       Theft from Building
# 1               Driving Under the Influence
# 2                               Shoplifting
# 3                 Trespass of Real Property
# 4  Destruction/Damage/Vandalism of Property
#
#                           Crime Name3 Police District Name  \
# 0                 LARCENY - FROM BLDG            ROCKVILLE
# 1  DRIVING UNDER THE INFLUENCE LIQUOR   MONTGOMERY VILLAGE
# 2               LARCENY - SHOPLIFTING            ROCKVILLE
# 3                         TRESPASSING              WHEATON
# 4          DAMAGE PROPERTY - BUSINESS   MONTGOMERY VILLAGE
#
#                Block Address           City State  Zip Code Agency  \
# 0    1700 BLK E JEFFERSON ST      ROCKVILLE    MD   20852.0   MCPD
# 1    100 BLK N FREDERICK AVE   GAITHERSBURG    MD   20877.0    GPD
# 2          5700 BLK  BOU AVE      ROCKVILLE    MD   20852.0   MCPD
# 3   11100 BLK  VEIRS MILL RD  SILVER SPRING    MD   20902.0   MCPD
# 4  18500 BLK N FREDERICK AVE   GAITHERSBURG    MD   20879.0    GPD
#
#                              Place Sector Beat  PRA  Address Number  \
# 0  Retail - Appliances/Electronics      A  1A1  270          1700.0
# 1              Street - In vehicle      P  6P2  428           100.0
# 2                Retail - Clothing      A  1A2  271          5700.0
# 3                    Retail - Mall      L  4L2  321         11100.0
# 4                   Retail - Other      R  6R2  545         18500.0
#
#   Street Prefix Street Name Street Suffix Street Type Police District Number  \
# 0             E   JEFFERSON           NaN          ST                     1D
# 1             N   FREDERICK           NaN         AVE                     6D
# 2           NaN         BOU           NaN         AVE                     1D
# 3           NaN  VEIRS MILL           NaN          RD                     4D
# 4             N   FREDERICK           NaN         AVE                     6D
#
#               Location
# 0  (39.0585, -77.1264)
# 1  (39.0944, -77.1517)
# 2   (39.056, -77.1136)
# 3  (39.0376, -77.0519)
# 4  (39.1606, -77.2209)

# %%
# Change datatype of the columns
# Numeric to String Datatype
df[['CR Number','Zip Code','Address Number']] = df[['CR Number','Zip Code','Address Number']].astype('str')

# String to Date Datatype
df[['Dispatch Date / Time','Start_Date_Time','End_Date_Time']] = df[['Dispatch Date / Time','Start_Date_Time'\
                                                                        ,'End_Date_Time']].astype('datetime64[ns]')

# Replace 'nan' string with actual NaN values across the entire DataFrame
df = df.replace('nan', pd.NA)

# Print Data type and summary of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432139 entries, 0 to 432138
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Offence Code            432139 non-null  object
#  1   CR Number               432139 non-null  object
#  2   Dispatch Date / Time    369661 non-null  datetime64[ns]
#  3   Start_Date_Time         432139 non-null  datetime64[ns]
#  4   End_Date_Time           197529 non-null  datetime64[ns]
#  5   NIBRS Code              432139 non-null  object
#  6   Victims                 432139 non-null  int64
#  7   Crime Name1             432139 non-null  object
#  8   Crime Name2             432139 non-null  object
#  9   Crime Name3             432139 non-null  object
#  10  Police District Name    431076 non-null  object
#  11  Block Address           397305 non-null  object
#  12  City                    432124 non-null  object
#  13  State                   422643 non-null  object
#  14  Zip Code                428821 non-null  object
#  15  Agency                  432139 non-null  object
#  16  Place                   432139 non-null  object
#  17  Sector                  432139 non-null  object
#  18  Beat                    432139 non-null  object
#  19  PRA                     432130 non-null  object
#  20  Address Number          397443 non-null  object
#  21  Street Prefix           19641 non-null   object
#  22  Street Name             431075 non-null  object
#  23  Street Suffix           5931 non-null    object
#  24  Street Type             430691 non-null  object
#  25  Police District Number  432139 non-null  object
#  26  Location                432139 non-null  object
# dtypes: datetime64[ns](3), int64(1), object(23)
# memory usage: 89.0+ MB

# %%
# Print a sample of the DataFrame
df.head(5)
# Out:
#   Offence Code  CR Number Dispatch Date / Time     Start_Date_Time  \
# 0         2308  170548599                  NaT 2017-12-14 16:30:00
# 1         5404  220000965  2022-01-09 01:18:38 2022-01-09 01:34:00
# 2         2303   16043118                  NaT 2016-08-24 21:47:00
# 3         5707   16037677                  NaT 2016-07-25 17:31:00
# 4         2901  220003839  2022-01-28 19:11:29 2022-01-28 14:40:00
#
#         End_Date_Time NIBRS Code  Victims             Crime Name1  \
# 0                 NaT        23D        1  Crime Against Property
# 1                 NaT        90D        1   Crime Against Society
# 2                 NaT        23C        1  Crime Against Property
# 3                 NaT        90J        1   Crime Against Society
# 4 2022-01-28 14:46:00        290        1  Crime Against Property
#
#                                 Crime Name2  \
# 0                       Theft from Building
# 1               Driving Under the Influence
# 2                               Shoplifting
# 3                 Trespass of Real Property
# 4  Destruction/Damage/Vandalism of Property
#
#                           Crime Name3 Police District Name  \
# 0                 LARCENY - FROM BLDG            ROCKVILLE
# 1  DRIVING UNDER THE INFLUENCE LIQUOR   MONTGOMERY VILLAGE
# 2               LARCENY - SHOPLIFTING            ROCKVILLE
# 3                         TRESPASSING              WHEATON
# 4          DAMAGE PROPERTY - BUSINESS   MONTGOMERY VILLAGE
#
#                Block Address           City State Zip Code Agency  \
# 0    1700 BLK E JEFFERSON ST      ROCKVILLE    MD  20852.0   MCPD
# 1    100 BLK N FREDERICK AVE   GAITHERSBURG    MD  20877.0    GPD
# 2          5700 BLK  BOU AVE      ROCKVILLE    MD  20852.0   MCPD
# 3   11100 BLK  VEIRS MILL RD  SILVER SPRING    MD  20902.0   MCPD
# 4  18500 BLK N FREDERICK AVE   GAITHERSBURG    MD  20879.0    GPD
#
#                              Place Sector Beat  PRA Address Number  \
# 0  Retail - Appliances/Electronics      A  1A1  270         1700.0
# 1              Street - In vehicle      P  6P2  428          100.0
# 2                Retail - Clothing      A  1A2  271         5700.0
# 3                    Retail - Mall      L  4L2  321        11100.0
# 4                   Retail - Other      R  6R2  545        18500.0
#
#   Street Prefix Street Name Street Suffix Street Type Police District Number  \
# 0             E   JEFFERSON           NaN          ST                     1D
# 1             N   FREDERICK           NaN         AVE                     6D
# 2           NaN         BOU           NaN         AVE                     1D
# 3           NaN  VEIRS MILL           NaN          RD                     4D
# 4             N   FREDERICK           NaN         AVE                     6D
#
#               Location
# 0  (39.0585, -77.1264)
# 1  (39.0944, -77.1517)
# 2   (39.056, -77.1136)
# 3  (39.0376, -77.0519)
# 4  (39.1606, -77.2209)

# %%
# Use regular expressions to remove decimal numbers
df[['Zip Code', 'Address Number']] = df[['Zip Code', 'Address Number']].applymap(
    lambda x: re.sub(r'\.\d+', '', x) if not pd.isna(x) else x
)

df.head()
# Out:
#   Offence Code  CR Number Dispatch Date / Time     Start_Date_Time  \
# 0         2308  170548599                  NaT 2017-12-14 16:30:00
# 1         5404  220000965  2022-01-09 01:18:38 2022-01-09 01:34:00
# 2         2303   16043118                  NaT 2016-08-24 21:47:00
# 3         5707   16037677                  NaT 2016-07-25 17:31:00
# 4         2901  220003839  2022-01-28 19:11:29 2022-01-28 14:40:00
#
#         End_Date_Time NIBRS Code  Victims             Crime Name1  \
# 0                 NaT        23D        1  Crime Against Property
# 1                 NaT        90D        1   Crime Against Society
# 2                 NaT        23C        1  Crime Against Property
# 3                 NaT        90J        1   Crime Against Society
# 4 2022-01-28 14:46:00        290        1  Crime Against Property
#
#                                 Crime Name2  \
# 0                       Theft from Building
# 1               Driving Under the Influence
# 2                               Shoplifting
# 3                 Trespass of Real Property
# 4  Destruction/Damage/Vandalism of Property
#
#                           Crime Name3 Police District Name  \
# 0                 LARCENY - FROM BLDG            ROCKVILLE
# 1  DRIVING UNDER THE INFLUENCE LIQUOR   MONTGOMERY VILLAGE
# 2               LARCENY - SHOPLIFTING            ROCKVILLE
# 3                         TRESPASSING              WHEATON
# 4          DAMAGE PROPERTY - BUSINESS   MONTGOMERY VILLAGE
#
#                Block Address           City State Zip Code Agency  \
# 0    1700 BLK E JEFFERSON ST      ROCKVILLE    MD    20852   MCPD
# 1    100 BLK N FREDERICK AVE   GAITHERSBURG    MD    20877    GPD
# 2          5700 BLK  BOU AVE      ROCKVILLE    MD    20852   MCPD
# 3   11100 BLK  VEIRS MILL RD  SILVER SPRING    MD    20902   MCPD
# 4  18500 BLK N FREDERICK AVE   GAITHERSBURG    MD    20879    GPD
#
#                              Place Sector Beat  PRA Address Number  \
# 0  Retail - Appliances/Electronics      A  1A1  270           1700
# 1              Street - In vehicle      P  6P2  428            100
# 2                Retail - Clothing      A  1A2  271           5700
# 3                    Retail - Mall      L  4L2  321          11100
# 4                   Retail - Other      R  6R2  545          18500
#
#   Street Prefix Street Name Street Suffix Street Type Police District Number  \
# 0             E   JEFFERSON           NaN          ST                     1D
# 1             N   FREDERICK           NaN         AVE                     6D
# 2           NaN         BOU           NaN         AVE                     1D
# 3           NaN  VEIRS MILL           NaN          RD                     4D
# 4             N   FREDERICK           NaN         AVE                     6D
#
#               Location
# 0  (39.0585, -77.1264)
# 1  (39.0944, -77.1517)
# 2   (39.056, -77.1136)
# 3  (39.0376, -77.0519)
# 4  (39.1606, -77.2209)

# %%
def generate_statistical_summary(df, data_type):
    if data_type == 'numeric':
        summary = df.describe(exclude=['object','datetime64'])
    elif data_type == 'object':
        summary = df.describe(include=['object'])
    elif data_type == 'datetime':
        summary = df.describe(include=['datetime64[ns]'])
    else:
        summary = "Invalid data type specified"
    return summary

# For numeric data
numeric_summary = generate_statistical_summary(df, 'numeric')
print("Statistical Summary for Numeric Data:")
print(tabulate(numeric_summary, headers='keys', tablefmt='pretty'))

# For object data
object_summary = generate_statistical_summary(df, 'object')
print("\nStatistical Summary for Object Data:")
print(tabulate(object_summary, headers='keys', tablefmt='pretty'))

# For datetime data
datetime_summary = generate_statistical_summary(df, 'datetime')
print("\nStatistical Summary for Datetime Data:")
print(tabulate(datetime_summary, headers='keys', tablefmt='pretty'))
# Out:
# Statistical Summary for Numeric Data:
# +-------+---------------------+
# |       |       Victims       |
# +-------+---------------------+
# | count |      432139.0       |
# | mean  |  1.021574076859529  |
# |  std  | 0.18380748360877433 |
# |  min  |         1.0         |
# |  25%  |         1.0         |
# |  50%  |         1.0         |
# |  75%  |         1.0         |
# |  max  |        22.0         |
# +-------+---------------------+
#
# Statistical Summary for Object Data:
# +--------+--------------+-----------+------------+------------------------+--------------------+---------------------+----------------------+--------------------------+---------------+--------+----------+--------+---------------------------+--------+--------+--------+----------------+---------------+-------------+---------------+-------------+------------------------+------------+
# |        | Offence Code | CR Number | NIBRS Code |      Crime Name1       |    Crime Name2     |     Crime Name3     | Police District Name |      Block Address       |     City      | State  | Zip Code | Agency |           Place           | Sector |  Beat  |  PRA   | Address Number | Street Prefix | Street Name | Street Suffix | Street Type | Police District Number |  Location  |
# +--------+--------------+-----------+------------+------------------------+--------------------+---------------------+----------------------+--------------------------+---------------+--------+----------+--------+---------------------------+--------+--------+--------+----------------+---------------+-------------+---------------+-------------+------------------------+------------+
# | count  |    432139    |  432139   |   432139   |         432139         |       432139       |       432139        |        431076        |          397305          |    432124     | 422643 |  428821  | 432139 |          432139           | 432139 | 432139 | 432130 |     397443     |     19641     |   431075    |     5931      |   430691    |         432139         |   432139   |
# | unique |     561      |  396532   |     56     |           4            |         56         |         353         |          8           |          22790           |      291      |   11   |   190    |   8    |            100            |   16   |   58   |  795   |      426       |       4       |    8011     |       6       |     35      |           8            |   29983    |
# |  top   |     2305     | 230071672 |    90Z     | Crime Against Property | All Other Offenses | LARCENY - FROM AUTO |    SILVER SPRING     | 11100 BLK  VEIRS MILL RD | SILVER SPRING |   MD   |  20910   |  MCPD  | Residence - Single Family |   P    |  3G1   |  702   |       1        |       E       |   GEORGIA   |       W       |     RD      |           3D           | (0.0, 0.0) |
# |  freq  |    35604     |     9     |   100433   |         209381         |       100433       |        35888        |        90691         |           5970           |    150215     | 422373 |  36567   | 370699 |           44558           | 41661  | 27701  |  7531  |     18762      |     7037      |    18148    |     3322      |   107098    |         90691          |   13126    |
# +--------+--------------+-----------+------------+------------------------+--------------------+---------------------+----------------------+--------------------------+---------------+--------+----------+--------+---------------------------+--------+--------+--------+----------------+---------------+-------------+---------------+-------------+------------------------+------------+
#
# Statistical Summary for Datetime Data:
# +-------+-------------------------------+-------------------------------+-------------------------------+
# |       |     Dispatch Date / Time      |        Start_Date_Time        |         End_Date_Time         |
# +-------+-------------------------------+-------------------------------+-------------------------------+
# | count |            369661             |            432139             |            197529             |
# | mean  | 2021-01-12 02:23:29.620279040 | 2020-08-26 17:43:01.787757824 | 2020-06-28 10:49:12.074480640 |
# |  min  |      2017-04-02 07:37:54      |      2016-07-01 00:00:00      |      2016-07-01 00:00:00      |
# |  25%  |      2019-01-10 15:17:40      |      2018-06-08 00:29:30      |      2018-03-31 02:00:00      |
# |  50%  |      2020-12-28 11:56:27      |      2020-07-14 12:00:00      |      2020-04-21 21:00:00      |
# |  75%  |      2022-12-23 12:29:50      |      2022-11-12 19:51:00      |      2022-09-15 10:07:00      |
# |  max  |      2025-02-10 18:15:54      |      2025-02-10 18:15:00      |      2025-02-10 18:45:00      |
# +-------+-------------------------------+-------------------------------+-------------------------------+

# %%
def calculate_missing_values(df):
  # Total percent of overall data
  total_percentage_missing = (
      (
          (df.isnull() | df.isna() | (df == '') | (df == '0')).sum().sum()
          / (df.size)
      ) * 100
  ).round(2)
  print(f"The total percentage of missing values is: {total_percentage_missing}% \n")

  # Count of missing values
  missing_count = (
      (df.isnull() | df.isna()).sum() +
      (df == '').sum() +
      (df == '0').sum()
  )

  # Percentage of missing values
  missing_percentage = (
      ((df.isnull() | df.isna()).sum() +
      (df == '').sum()+
      (df == '0').sum()) * 100 / len(df)
  ).round(2)

  # Create a DataFrame to store the results
  statistical_df = pd.DataFrame({
      "Count of Missing Values": missing_count,
      "Percentage of Missing Values (%)": missing_percentage
  })

  # Print the combined table
  print("Combined Summary Table:")
  print(tabulate(statistical_df, headers='keys', tablefmt='pretty'))

calculate_missing_values(df)
# Out:
# The total percentage of missing values is: 10.47%
#
# Combined Summary Table:
# +------------------------+-------------------------+----------------------------------+
# |                        | Count of Missing Values | Percentage of Missing Values (%) |
# +------------------------+-------------------------+----------------------------------+
# |      Offence Code      |           0.0           |               0.0                |
# |       CR Number        |           0.0           |               0.0                |
# |  Dispatch Date / Time  |         62478.0         |              14.46               |
# |    Start_Date_Time     |           0.0           |               0.0                |
# |     End_Date_Time      |        234610.0         |              54.29               |
# |       NIBRS Code       |           0.0           |               0.0                |
# |        Victims         |           0.0           |               0.0                |
# |      Crime Name1       |           0.0           |               0.0                |
# |      Crime Name2       |           0.0           |               0.0                |
# |      Crime Name3       |           0.0           |               0.0                |
# |  Police District Name  |         1063.0          |               0.25               |
# |     Block Address      |         34834.0         |               8.06               |
# |          City          |          16.0           |               0.0                |
# |         State          |         9497.0          |               2.2                |
# |        Zip Code        |         3318.0          |               0.77               |
# |         Agency         |           0.0           |               0.0                |
# |         Place          |           0.0           |               0.0                |
# |         Sector         |           0.0           |               0.0                |
# |          Beat          |           0.0           |               0.0                |
# |          PRA           |           9.0           |               0.0                |
# |     Address Number     |         34697.0         |               8.03               |
# |     Street Prefix      |        412498.0         |              95.45               |
# |      Street Name       |         1064.0          |               0.25               |
# |     Street Suffix      |        426208.0         |              98.63               |
# |      Street Type       |         1448.0          |               0.34               |
# | Police District Number |           0.0           |               0.0                |
# |        Location        |           0.0           |               0.0                |
# +------------------------+-------------------------+----------------------------------+

# %%
# Drop columns
df.drop(['Block Address','Address Number','Street Prefix','Street Suffix'],axis=1, inplace=True)

# Print list of columns in the DataFrame
df.columns
# Out:
# Index(['Offence Code', 'CR Number', 'Dispatch Date / Time', 'Start_Date_Time',
#        'End_Date_Time', 'NIBRS Code', 'Victims', 'Crime Name1', 'Crime Name2',
#        'Crime Name3', 'Police District Name', 'City', 'State', 'Zip Code',
#        'Agency', 'Place', 'Sector', 'Beat', 'PRA', 'Street Name',
#        'Street Type', 'Police District Number', 'Location'],
#       dtype='object')

# %%
count_Loc_0_0 = (df['Location'].str.contains('0.0, 0.0') | df['Location'].str.contains('90.0')).sum()
percentage_Loc_0_0 = round((count_Loc_0_0 / df.size) * 100, 2)
print(f"Total count of Locations having values '0.0, 0.0' and '90.0' is {count_Loc_0_0} which is {percentage_Loc_0_0}% of overall data.\n")
# Out:
# Total count of Locations having values '0.0, 0.0' and '90.0' is 13126 which is 0.13% of overall data.

# %%
# Create DataFrame excluding specific locations
df_loc = df[~df['Location'].str.contains('0.0, 0.0') & ~df['Location'].str.contains('90.0')]

# Remove parentheses
df_loc['Location'] = df_loc['Location'].str.replace(r'[()]', '', regex=True)

# Print a sample DataFrame
df_loc.head()
# Out:
#   Offence Code  CR Number Dispatch Date / Time     Start_Date_Time  \
# 0         2308  170548599                  NaT 2017-12-14 16:30:00
# 1         5404  220000965  2022-01-09 01:18:38 2022-01-09 01:34:00
# 2         2303   16043118                  NaT 2016-08-24 21:47:00
# 3         5707   16037677                  NaT 2016-07-25 17:31:00
# 4         2901  220003839  2022-01-28 19:11:29 2022-01-28 14:40:00
#
#         End_Date_Time NIBRS Code  Victims             Crime Name1  \
# 0                 NaT        23D        1  Crime Against Property
# 1                 NaT        90D        1   Crime Against Society
# 2                 NaT        23C        1  Crime Against Property
# 3                 NaT        90J        1   Crime Against Society
# 4 2022-01-28 14:46:00        290        1  Crime Against Property
#
#                                 Crime Name2  \
# 0                       Theft from Building
# 1               Driving Under the Influence
# 2                               Shoplifting
# 3                 Trespass of Real Property
# 4  Destruction/Damage/Vandalism of Property
#
#                           Crime Name3 Police District Name           City  \
# 0                 LARCENY - FROM BLDG            ROCKVILLE      ROCKVILLE
# 1  DRIVING UNDER THE INFLUENCE LIQUOR   MONTGOMERY VILLAGE   GAITHERSBURG
# 2               LARCENY - SHOPLIFTING            ROCKVILLE      ROCKVILLE
# 3                         TRESPASSING              WHEATON  SILVER SPRING
# 4          DAMAGE PROPERTY - BUSINESS   MONTGOMERY VILLAGE   GAITHERSBURG
#
#   State Zip Code Agency                            Place Sector Beat  PRA  \
# 0    MD    20852   MCPD  Retail - Appliances/Electronics      A  1A1  270
# 1    MD    20877    GPD              Street - In vehicle      P  6P2  428
# 2    MD    20852   MCPD                Retail - Clothing      A  1A2  271
# 3    MD    20902   MCPD                    Retail - Mall      L  4L2  321
# 4    MD    20879    GPD                   Retail - Other      R  6R2  545
#
#   Street Name Street Type Police District Number           Location
# 0   JEFFERSON          ST                     1D  39.0585, -77.1264
# 1   FREDERICK         AVE                     6D  39.0944, -77.1517
# 2         BOU         AVE                     1D   39.056, -77.1136
# 3  VEIRS MILL          RD                     4D  39.0376, -77.0519
# 4   FREDERICK         AVE                     6D  39.1606, -77.2209

# %%
# Retrieve the list of columns with missing/blank values
na_var = [var for var in df_loc.columns if df_loc[var].isnull().sum() > 0
          or (df_loc[var] == '').sum() > 0]

# Create a DataFrame for better presentation
naVar_df = pd.DataFrame({"Variables with Missing/Blank values": na_var})
print("Combined Summary Table:")
print(tabulate(naVar_df, headers='keys', tablefmt='pretty'))
# Out:
# Combined Summary Table:
# +---+-------------------------------------+
# |   | Variables with Missing/Blank values |
# +---+-------------------------------------+
# | 0 |        Dispatch Date / Time         |
# | 1 |            End_Date_Time            |
# | 2 |                City                 |
# | 3 |                State                |
# | 4 |              Zip Code               |
# | 5 |                 PRA                 |
# | 6 |             Street Type             |
# +---+-------------------------------------+

# %%
# Drop rows where 'Sector', 'Beat' and 'PRA' have missing
df_loc.dropna(subset=['Sector','Beat','PRA'], inplace=True)

# %%
# drop rows where Street Name is missing
df_loc = df_loc[df_loc['Street Name']!='0']

# %%
# Set up Google Maps client with your API key
gmaps = googlemaps.Client(key='AIzaSyDSF-KKsdLnE1TQyj2ayORKehzCCIM5QUY')  # Replace with your actual Google Maps API key

def update_zip(row):
    # Check if zip code is missing or has less than 5 characters
    if pd.isna(row['Zip Code']) or len(str(row['Zip Code']).strip()) < 5:
        try:
            # Extract latitude and longitude from the location
            lat, lng = map(float, row['Location'].split(', '))
            # Get the address from Google Maps API
            results = gmaps.reverse_geocode((lat, lng))
            # Introduce a delay to avoid hitting rate limits
            time.sleep(0.1)  # 100 milliseconds delay
            # Extract the zip code from the results
            for result in results:
                for component in result['address_components']:
                    if 'postal_code' in component['types']:
                        return component['long_name']
        except Exception as e:
            print(f"Error processing row: {row}, Error: {e}")

    return row['Zip Code']


# Update the zip codes
df_loc['Zip Code'] = df_loc.apply(update_zip, axis=1)
# Out:
# Error processing row: Offence Code                                2308
# CR Number                               16058712
# Dispatch Date / Time                         NaT
# Start_Date_Time              2016-11-12 15:00:00
# End_Date_Time                2016-11-12 15:02:00
# NIBRS Code                                   23D
# Victims                                        1
# Crime Name1               Crime Against Property
# Crime Name2                  Theft from Building
# Crime Name3                  LARCENY - FROM BLDG
# Police District Name                    BETHESDA
# City                                    BETHESDA
# State                                         MD
# Zip Code                                    <NA>
# Agency                                      MCPD
# Place                          Retail - Clothing
# Sector                                         E
# Beat                                         2E3
# PRA                                          204
# Street Name                            DEMOCRACY
# Street Type                                  BLV
# Police District Number                        2D
# Location                       39.0221, -77.1473
# Name: 17, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                     3562
# CR Number                                    16035928
# Dispatch Date / Time                              NaT
# Start_Date_Time                   2016-07-15 17:47:00
# End_Date_Time                                     NaT
# NIBRS Code                                        35A
# Victims                                             1
# Crime Name1                     Crime Against Society
# Crime Name2                  Drug/Narcotic Violations
# Crime Name3               DRUGS - MARIJUANA - POSSESS
# Police District Name               MONTGOMERY VILLAGE
# City                                     GAITHERSBURG
# State                                              MD
# Zip Code                                         <NA>
# Agency                                           MCPD
# Place                             Street - In vehicle
# Sector                                              P
# Beat                                              6P3
# PRA                                               432
# Street Name                                 FREDERICK
# Street Type                                       AVE
# Police District Number                             6D
# Location                            39.1457, -77.2037
# Name: 2811, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                               4104
# CR Number                              16035894
# Dispatch Date / Time                        NaT
# Start_Date_Time             2016-07-15 15:41:00
# End_Date_Time                               NaT
# NIBRS Code                                  90G
# Victims                                       1
# Crime Name1               Crime Against Society
# Crime Name2               Liquor Law Violations
# Crime Name3                    LIQUOR - POSSESS
# Police District Name                    WHEATON
# City                                        MCG
# State                                       NaN
# Zip Code                                   <NA>
# Agency                                     MCPD
# Place                            Retail - Other
# Sector                                        L
# Beat                                        4L2
# PRA                                         355
# Street Name                             GEORGIA
# Street Type                                 AVE
# Police District Number                       4D
# Location                      39.0415, -77.0517
# Name: 2883, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                                    2605
# CR Number                                                   16037609
# Dispatch Date / Time                                             NaT
# Start_Date_Time                                  2016-07-23 12:00:00
# End_Date_Time                                    2016-07-24 12:30:00
# NIBRS Code                                                       26B
# Victims                                                            1
# Crime Name1                                   Crime Against Property
# Crime Name2               Credit Card/Automatic Teller Machine Fraud
# Crime Name3                         FRAUD - ILLEGAL USE CREDIT CARDS
# Police District Name                                       ROCKVILLE
# City                                                       ROCKVILLE
# State                                                             MD
# Zip Code                                                        <NA>
# Agency                                                          MCPD
# Place                                                  Other/Unknown
# Sector                                                             A
# Beat                                                             1A1
# PRA                                                              270
# Street Name                                               CALIFORNIA
# Street Type                                                      CIR
# Police District Number                                            1D
# Location                                           39.0559, -77.1209
# Name: 3967, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                  2305
# CR Number                                 16038127
# Dispatch Date / Time                           NaT
# Start_Date_Time                2016-07-28 02:43:00
# End_Date_Time                                  NaT
# NIBRS Code                                     23F
# Victims                                          1
# Crime Name1                 Crime Against Property
# Crime Name2               Theft From Motor Vehicle
# Crime Name3                    LARCENY - FROM AUTO
# Police District Name                   TAKOMA PARK
# City                                            TP
# State                                          NaN
# Zip Code                                      <NA>
# Agency                                        TPPD
# Place                         Street - Residential
# Sector                                           T
# Beat                                           8T2
# PRA                                            804
# Street Name                                SHERMAN
# Street Type                                    AVE
# Police District Number                        TPPD
# Location                         38.9797, -77.0047
# Name: 4362, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                  2305
# CR Number                                 16039589
# Dispatch Date / Time                           NaT
# Start_Date_Time                2016-08-04 19:00:00
# End_Date_Time                  2016-08-05 04:50:00
# NIBRS Code                                     23F
# Victims                                          1
# Crime Name1                 Crime Against Property
# Crime Name2               Theft From Motor Vehicle
# Crime Name3                    LARCENY - FROM AUTO
# Police District Name                    GERMANTOWN
# City                                    GERMANTOWN
# State                                           MD
# Zip Code                                      <NA>
# Agency                                        MCPD
# Place                         Street - Residential
# Sector                                           M
# Beat                                           5M3
# PRA                                            474
# Street Name                                  VADEN
# Street Type                                    TER
# Police District Number                          5D
# Location                         39.2079, -77.2685
# Name: 5172, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                   1399
# CR Number                                  16040365
# Dispatch Date / Time                            NaT
# Start_Date_Time                 2016-08-09 14:00:00
# End_Date_Time                   2016-08-09 14:15:00
# NIBRS Code                                      13B
# Victims                                           1
# Crime Name1                    Crime Against Person
# Crime Name2                          Simple Assault
# Crime Name3                    ASSAULT - 2ND DEGREE
# Police District Name             MONTGOMERY VILLAGE
# City                                   GAITHERSBURG
# State                                            MD
# Zip Code                                       2088
# Agency                                         MCPD
# Place                     Residence - Single Family
# Sector                                            P
# Beat                                            6P1
# PRA                                             553
# Street Name                           REDDING RIDGE
# Street Type                                      DR
# Police District Number                           6D
# Location                          39.1052, -77.2254
# Name: 5644, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                                2203
# CR Number                                               16041351
# Dispatch Date / Time                                         NaT
# Start_Date_Time                              2016-08-15 12:06:00
# End_Date_Time                                2016-08-15 12:45:00
# NIBRS Code                                                   220
# Victims                                                        1
# Crime Name1                               Crime Against Property
# Crime Name2                       Burglary/Breaking and Entering
# Crime Name3               BURGLARY - FORCED ENTRY-NONRESIDENTIAL
# Police District Name                                  GERMANTOWN
# City                                                  GERMANTOWN
# State                                                         MD
# Zip Code                                                    <NA>
# Agency                                                      MCPD
# Place                                                       Pool
# Sector                                                         M
# Beat                                                         5M2
# PRA                                                          615
# Street Name                                            WOODFIELD
# Street Type                                                   RD
# Police District Number                                        5D
# Location                                       39.2784, -77.2036
# Name: 6312, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                  2305
# CR Number                                 16042324
# Dispatch Date / Time                           NaT
# Start_Date_Time                2016-08-20 11:00:00
# End_Date_Time                  2016-08-20 13:00:00
# NIBRS Code                                     23F
# Victims                                          1
# Crime Name1                 Crime Against Property
# Crime Name2               Theft From Motor Vehicle
# Crime Name3                    LARCENY - FROM AUTO
# Police District Name                      BETHESDA
# City                                       POTOMAC
# State                                           MD
# Zip Code                                      <NA>
# Agency                                        MCPD
# Place                          Street - Commercial
# Sector                                           E
# Beat                                           2E4
# PRA                                            214
# Street Name                             MAC ARTHUR
# Street Type                                    BLV
# Police District Number                          2D
# Location                         38.9846, -77.2268
# Name: 7084, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                2308
# CR Number                               16043120
# Dispatch Date / Time                         NaT
# Start_Date_Time              2016-08-24 16:30:00
# End_Date_Time                2016-08-24 19:00:00
# NIBRS Code                                   23D
# Victims                                        1
# Crime Name1               Crime Against Property
# Crime Name2                  Theft from Building
# Crime Name3                  LARCENY - FROM BLDG
# Police District Name                    BETHESDA
# City                                    BETHESDA
# State                                         MD
# Zip Code                                    <NA>
# Agency                                      MCPD
# Place                                 Restaurant
# Sector                                         D
# Beat                                         2D2
# PRA                                          033
# Street Name                                  ELM
# Street Type                                   ST
# Police District Number                        2D
# Location                        38.9821, -77.096
# Name: 7431, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                2303
# CR Number                               16049929
# Dispatch Date / Time                         NaT
# Start_Date_Time              2016-09-28 10:00:00
# End_Date_Time                                NaT
# NIBRS Code                                   23C
# Victims                                        1
# Crime Name1               Crime Against Property
# Crime Name2                          Shoplifting
# Crime Name3                LARCENY - SHOPLIFTING
# Police District Name                 TAKOMA PARK
# City                                          TP
# State                                        NaN
# Zip Code                                    <NA>
# Agency                                      TPPD
# Place                                Auto Repair
# Sector                                         T
# Beat                                         8T1
# PRA                                          802
# Street Name                        NEW HAMPSHIRE
# Street Type                                  AVE
# Police District Number                      TPPD
# Location                       38.9657, -77.0024
# Name: 11827, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                                    2605
# CR Number                                                   16050138
# Dispatch Date / Time                                             NaT
# Start_Date_Time                                  2016-09-24 13:00:00
# End_Date_Time                                    2016-09-29 13:00:00
# NIBRS Code                                                       26B
# Victims                                                            1
# Crime Name1                                   Crime Against Property
# Crime Name2               Credit Card/Automatic Teller Machine Fraud
# Crime Name3                         FRAUD - ILLEGAL USE CREDIT CARDS
# Police District Name                                   SILVER SPRING
# City                                                   SILVER SPRING
# State                                                             MD
# Zip Code                                                        <NA>
# Agency                                                          MCPD
# Place                                                  Other/Unknown
# Sector                                                             G
# Beat                                                             3G1
# PRA                                                              109
# Street Name                                               COLESVILLE
# Street Type                                                       RD
# Police District Number                                            3D
# Location                                            38.996, -77.0281
# Name: 12003, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                            2399
# CR Number                                           16054301
# Dispatch Date / Time                                     NaT
# Start_Date_Time                          2016-10-21 17:47:00
# End_Date_Time                                            NaT
# NIBRS Code                                               23H
# Victims                                                    1
# Crime Name1                           Crime Against Property
# Crime Name2                                All other Larceny
# Crime Name3                       LARCENY (DESCRIBE OFFENSE)
# Police District Name                              GERMANTOWN
# City                                              GERMANTOWN
# State                                                     MD
# Zip Code                                                <NA>
# Agency                                                  MCPD
# Place                     Retail - Department/Discount Store
# Sector                                                     M
# Beat                                                     5M1
# PRA                                                      701
# Street Name                                        FREDERICK
# Street Type                                               RD
# Police District Number                                    5D
# Location                                   39.1983, -77.2448
# Name: 14811, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                   2305
# CR Number                                  16054852
# Dispatch Date / Time                            NaT
# Start_Date_Time                 2016-10-25 08:10:00
# End_Date_Time                                   NaT
# NIBRS Code                                      23F
# Victims                                           1
# Crime Name1                  Crime Against Property
# Crime Name2                Theft From Motor Vehicle
# Crime Name3                     LARCENY - FROM AUTO
# Police District Name                     GERMANTOWN
# City                                     GERMANTOWN
# State                                            MD
# Zip Code                                       <NA>
# Agency                                         MCPD
# Place                     Parking Lot - Residential
# Sector                                            N
# Beat                                            5N1
# PRA                                             595
# Street Name                            CRYSTAL ROCK
# Street Type                                      DR
# Police District Number                           5D
# Location                           39.179, -77.2616
# Name: 15190, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                2308
# CR Number                               16055315
# Dispatch Date / Time                         NaT
# Start_Date_Time              2016-10-27 10:20:00
# End_Date_Time                2016-10-27 10:28:00
# NIBRS Code                                   23D
# Victims                                        1
# Crime Name1               Crime Against Property
# Crime Name2                  Theft from Building
# Crime Name3                  LARCENY - FROM BLDG
# Police District Name                    BETHESDA
# City                                    BETHESDA
# State                                         MD
# Zip Code                                    <NA>
# Agency                                      MCPD
# Place                           Hotel/Motel/Etc.
# Sector                                         D
# Beat                                         2D2
# PRA                                          049
# Street Name                            WISCONSIN
# Street Type                                  AVE
# Police District Number                        2D
# Location                       38.9912, -77.0956
# Name: 15636, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                                  2999
# CR Number                                                 16056279
# Dispatch Date / Time                                           NaT
# Start_Date_Time                                2016-10-31 22:40:00
# End_Date_Time                                  2016-11-01 14:00:00
# NIBRS Code                                                     290
# Victims                                                          1
# Crime Name1                                 Crime Against Property
# Crime Name2               Destruction/Damage/Vandalism of Property
# Crime Name3                     DAMAGE PROPERTY (DESCRIBE OFFENSE)
# Police District Name                                     ROCKVILLE
# City                                                     ROCKVILLE
# State                                                           MD
# Zip Code                                                      <NA>
# Agency                                                        RCPD
# Place                                         Residence - Driveway
# Sector                                                           A
# Beat                                                           1A3
# PRA                                                            282
# Street Name                                                  MOORE
# Street Type                                                     DR
# Police District Number                                          1D
# Location                                         39.0952, -77.1464
# Name: 16152, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                     3562
# CR Number                                    16057903
# Dispatch Date / Time                              NaT
# Start_Date_Time                   2016-11-09 21:59:00
# End_Date_Time                                     NaT
# NIBRS Code                                        35A
# Victims                                             1
# Crime Name1                     Crime Against Society
# Crime Name2                  Drug/Narcotic Violations
# Crime Name3               DRUGS - MARIJUANA - POSSESS
# Police District Name               MONTGOMERY VILLAGE
# City                                              MCG
# State                                             NaN
# Zip Code                                         <NA>
# Agency                                           MCPD
# Place                             Street - In vehicle
# Sector                                              R
# Beat                                              6R1
# PRA                                               426
# Street Name                            WALKERS CHOICE
# Street Type                                        RD
# Police District Number                             6D
# Location                            39.1615, -77.2028
# Name: 17417, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                    2399
# CR Number                                   16059245
# Dispatch Date / Time                             NaT
# Start_Date_Time                  2016-11-15 00:00:00
# End_Date_Time                    2016-11-16 13:30:00
# NIBRS Code                                       23H
# Victims                                            1
# Crime Name1                   Crime Against Property
# Crime Name2                        All other Larceny
# Crime Name3               LARCENY (DESCRIBE OFFENSE)
# Police District Name              MONTGOMERY VILLAGE
# City                                    GAITHERSBURG
# State                                             MD
# Zip Code                                        <NA>
# Agency                                          MCPD
# Place                              Residence - Other
# Sector                                             P
# Beat                                             6P3
# PRA                                              432
# Street Name                                  DOGWOOD
# Street Type                                       DR
# Police District Number                            6D
# Location                           39.1389, -77.1909
# Name: 18708, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                     3562
# CR Number                                    16059951
# Dispatch Date / Time                              NaT
# Start_Date_Time                   2016-11-21 18:50:00
# End_Date_Time                                     NaT
# NIBRS Code                                        35A
# Victims                                             1
# Crime Name1                     Crime Against Society
# Crime Name2                  Drug/Narcotic Violations
# Crime Name3               DRUGS - MARIJUANA - POSSESS
# Police District Name                       GERMANTOWN
# City                                       GERMANTOWN
# State                                              MD
# Zip Code                                         <NA>
# Agency                                           MCPD
# Place                        Parking Lot - Commercial
# Sector                                              N
# Beat                                              5N1
# PRA                                               702
# Street Name                                   CENTURY
# Street Type                                       BLV
# Police District Number                             5D
# Location                            39.1829, -77.2636
# Name: 18787, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                      2308
# CR Number                                     16061095
# Dispatch Date / Time                               NaT
# Start_Date_Time                    2016-10-28 12:00:00
# End_Date_Time                      2016-11-28 12:00:00
# NIBRS Code                                         23D
# Victims                                              1
# Crime Name1                     Crime Against Property
# Crime Name2                        Theft from Building
# Crime Name3                        LARCENY - FROM BLDG
# Police District Name                          BETHESDA
# City                                          BETHESDA
# State                                               MD
# Zip Code                                          <NA>
# Agency                                            MCPD
# Place                     Commercial - Office Building
# Sector                                               D
# Beat                                               2D2
# PRA                                                033
# Street Name                                   BETHESDA
# Street Type                                         LA
# Police District Number                              2D
# Location                             38.9809, -77.0977
# Name: 19689, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                            5404
# CR Number                                           16062030
# Dispatch Date / Time                                     NaT
# Start_Date_Time                          2016-12-03 01:37:00
# End_Date_Time                            2016-12-03 01:37:00
# NIBRS Code                                               90D
# Victims                                                    1
# Crime Name1                            Crime Against Society
# Crime Name2                      Driving Under the Influence
# Crime Name3               DRIVING UNDER THE INFLUENCE LIQUOR
# Police District Name                      MONTGOMERY VILLAGE
# City                                            GAITHERSBURG
# State                                                     MD
# Zip Code                                                <NA>
# Agency                                                  MCPD
# Place                                    Street - In vehicle
# Sector                                                     P
# Beat                                                     6P1
# PRA                                                      444
# Street Name                                 N270CD X9 TO X10
# Street Type                                              HWY
# Police District Number                                    6D
# Location                                   39.1311, -77.2056
# Name: 20259, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                                 2699
# CR Number                                                16063205
# Dispatch Date / Time                                          NaT
# Start_Date_Time                               2016-11-30 21:00:00
# End_Date_Time                                                 NaT
# NIBRS Code                                                    26A
# Victims                                                         1
# Crime Name1                                Crime Against Property
# Crime Name2               False Pretenses/Swindle/Confidence Game
# Crime Name3                              FRAUD (DESCRIBE OFFENSE)
# Police District Name                           MONTGOMERY VILLAGE
# City                                                           GA
# State                                                         NaN
# Zip Code                                                     <NA>
# Agency                                                        GPD
# Place                                               Retail - Mall
# Sector                                                          R
# Beat                                                          6R1
# PRA                                                           548
# Street Name                                               RUSSELL
# Street Type                                                   AVE
# Police District Number                                         6D
# Location                                        39.1506, -77.2039
# Name: 21136, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                    2404
# CR Number                                  230066881
# Dispatch Date / Time             2023-11-17 10:49:05
# Start_Date_Time                  2023-11-17 10:49:00
# End_Date_Time                                    NaT
# NIBRS Code                                       240
# Victims                                            1
# Crime Name1                   Crime Against Property
# Crime Name2                      Motor Vehicle Theft
# Crime Name3               AUTO THEFT - VEHICLE THEFT
# Police District Name                           OTHER
# City                                    GAITHERSBURG
# State                                             MD
# Zip Code                                        <NA>
# Agency                                          MCPD
# Place                           Street - Residential
# Sector                                             w
# Beat                                             own
# PRA                                          Unknown
# Street Name                             WATKINS MILL
# Street Type                                       RD
# Police District Number                       Unknown
# Location                           39.1659, -77.2145
# Name: 21354, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                     2305
# CR Number                                    16063854
# Dispatch Date / Time                              NaT
# Start_Date_Time                   2016-12-12 17:30:00
# End_Date_Time                     2016-12-12 21:30:00
# NIBRS Code                                        23F
# Victims                                             1
# Crime Name1                    Crime Against Property
# Crime Name2                  Theft From Motor Vehicle
# Crime Name3                       LARCENY - FROM AUTO
# Police District Name                    SILVER SPRING
# City                                    SILVER SPRING
# State                                              MD
# Zip Code                                         <NA>
# Agency                                           MCPD
# Place                     Parking Garage - Commercial
# Sector                                              G
# Beat                                              3G1
# PRA                                               090
# Street Name                                   KENNETT
# Street Type                                        ST
# Police District Number                             3D
# Location                            38.9873, -77.0277
# Name: 21464, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                2303
# CR Number                               16064907
# Dispatch Date / Time                         NaT
# Start_Date_Time              2016-12-18 17:45:00
# End_Date_Time                2016-12-18 17:50:00
# NIBRS Code                                   23C
# Victims                                        1
# Crime Name1               Crime Against Property
# Crime Name2                          Shoplifting
# Crime Name3                LARCENY - SHOPLIFTING
# Police District Name               SILVER SPRING
# City                                         MCG
# State                                        NaN
# Zip Code                                    <NA>
# Agency                                      MCPD
# Place                        Grocery/Supermarket
# Sector                                         G
# Beat                                         3G1
# PRA                                          671
# Street Name                                WAYNE
# Street Type                                  AVE
# Police District Number                        3D
# Location                       38.9972, -77.0218
# Name: 22062, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                            2303
# CR Number                                           16065317
# Dispatch Date / Time                                     NaT
# Start_Date_Time                          2016-12-11 18:00:00
# End_Date_Time                                            NaT
# NIBRS Code                                               23C
# Victims                                                    1
# Crime Name1                           Crime Against Property
# Crime Name2                                      Shoplifting
# Crime Name3                            LARCENY - SHOPLIFTING
# Police District Name                      MONTGOMERY VILLAGE
# City                                            GAITHERSBURG
# State                                                     MD
# Zip Code                                                <NA>
# Agency                                                   GPD
# Place                     Retail - Department/Discount Store
# Sector                                                     R
# Beat                                                     6R1
# PRA                                                      548
# Street Name                                          RUSSELL
# Street Type                                              AVE
# Police District Number                                    6D
# Location                                   39.1506, -77.2039
# Name: 22410, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                  2305
# CR Number                                 16065558
# Dispatch Date / Time                           NaT
# Start_Date_Time                2016-12-21 19:14:00
# End_Date_Time                                  NaT
# NIBRS Code                                     23F
# Victims                                          1
# Crime Name1                 Crime Against Property
# Crime Name2               Theft From Motor Vehicle
# Crime Name3                    LARCENY - FROM AUTO
# Police District Name            MONTGOMERY VILLAGE
# City                                  GAITHERSBURG
# State                                           MD
# Zip Code                                      <NA>
# Agency                                        MCPD
# Place                     Parking Lot - Commercial
# Sector                                           P
# Beat                                           6P1
# PRA                                            550
# Street Name                           MUDDY BRANCH
# Street Type                                     RD
# Police District Number                          6D
# Location                           39.13, -77.2073
# Name: 22459, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                    2404
# CR Number                                   16066274
# Dispatch Date / Time                             NaT
# Start_Date_Time                  2016-12-25 07:39:00
# End_Date_Time                    2016-12-25 08:46:00
# NIBRS Code                                       240
# Victims                                            1
# Crime Name1                   Crime Against Property
# Crime Name2                      Motor Vehicle Theft
# Crime Name3               AUTO THEFT - VEHICLE THEFT
# Police District Name                      GERMANTOWN
# City                                      GERMANTOWN
# State                                             MD
# Zip Code                                        <NA>
# Agency                                          MCPD
# Place                           Street - Residential
# Sector                                             N
# Beat                                             5N1
# PRA                                              465
# Street Name                             CRYSTAL HILL
# Street Type                                      CIR
# Police District Number                            5D
# Location                           39.1965, -77.2757
# Name: 22908, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                                 2699
# CR Number                                                16066924
# Dispatch Date / Time                                          NaT
# Start_Date_Time                               2016-12-29 10:54:00
# End_Date_Time                                                 NaT
# NIBRS Code                                                    26A
# Victims                                                         1
# Crime Name1                                Crime Against Property
# Crime Name2               False Pretenses/Swindle/Confidence Game
# Crime Name3                              FRAUD (DESCRIBE OFFENSE)
# Police District Name                                  TAKOMA PARK
# City                                                  TAKOMA PARK
# State                                                          MD
# Zip Code                                                     <NA>
# Agency                                                       TPPD
# Place                                               Other/Unknown
# Sector                                                          T
# Beat                                                          8T2
# PRA                                                           803
# Street Name                                               ROANOKE
# Street Type                                                   AVE
# Police District Number                                       TPPD
# Location                                        38.9925, -77.0042
# Name: 23411, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                     2308
# CR Number                                    17001563
# Dispatch Date / Time                              NaT
# Start_Date_Time                   2017-01-09 13:30:00
# End_Date_Time                     2017-01-09 14:00:00
# NIBRS Code                                        23D
# Victims                                             1
# Crime Name1                    Crime Against Property
# Crime Name2                       Theft from Building
# Crime Name3                       LARCENY - FROM BLDG
# Police District Name                       GERMANTOWN
# City                                       GERMANTOWN
# State                                              MD
# Zip Code                                         <NA>
# Agency                                           MCPD
# Place                     School/College - DO NOT USE
# Sector                                              N
# Beat                                              5N1
# PRA                                               447
# Street Name                            WARING STATION
# Street Type                                        RD
# Police District Number                             5D
# Location                            39.1647, -77.2473
# Name: 24885, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                              1313
# CR Number                             17002802
# Dispatch Date / Time                       NaT
# Start_Date_Time            2017-01-16 17:30:00
# End_Date_Time              2017-01-16 17:45:00
# NIBRS Code                                 13B
# Victims                                      1
# Crime Name1               Crime Against Person
# Crime Name2                     Simple Assault
# Crime Name3                   ASSAULT - SIMPLE
# Police District Name               TAKOMA PARK
# City                                        TP
# State                                      NaN
# Zip Code                                  <NA>
# Agency                                    TPPD
# Place                        Residence - Other
# Sector                                       T
# Beat                                       8T2
# PRA                                        804
# Street Name                              MAPLE
# Street Type                                AVE
# Police District Number                    TPPD
# Location                      38.984, -77.0052
# Name: 25855, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                                    2605
# CR Number                                                   17003253
# Dispatch Date / Time                                             NaT
# Start_Date_Time                                  2017-01-18 09:00:00
# End_Date_Time                                                    NaT
# NIBRS Code                                                       26B
# Victims                                                            1
# Crime Name1                                   Crime Against Property
# Crime Name2               Credit Card/Automatic Teller Machine Fraud
# Crime Name3                         FRAUD - ILLEGAL USE CREDIT CARDS
# Police District Name                              MONTGOMERY VILLAGE
# City                                                    GAITHERSBURG
# ...
# Crime Name3               DRUGS - MARIJUANA - POSSESS
# Police District Name                       GERMANTOWN
# City                                       CLARKSBURG
# State                                              MD
# Zip Code                                         <NA>
# Agency                                           MCPD
# Place                             Street - In vehicle
# Sector                                              M
# Beat                                              5M3
# PRA                                               486
# Street Name                           S270 X18 TO X16
# Street Type                                       HWY
# Police District Number                             5D
# Location                             39.202, -77.2678
# Name: 108355, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                                 2699
# CR Number                                                17013156
# Dispatch Date / Time                                          NaT
# Start_Date_Time                               2017-03-07 10:00:00
# End_Date_Time                                 2017-03-13 13:10:00
# NIBRS Code                                                    26A
# Victims                                                         1
# Crime Name1                                Crime Against Property
# Crime Name2               False Pretenses/Swindle/Confidence Game
# Crime Name3                              FRAUD (DESCRIBE OFFENSE)
# Police District Name                                   GERMANTOWN
# City                                                   GERMANTOWN
# State                                                          MD
# Zip Code                                                     <NA>
# Agency                                                       MCPD
# Place                                Retail - Drug Store/Pharmacy
# Sector                                                          N
# Beat                                                          5N2
# PRA                                                           448
# Street Name                                           LEAMAN FARM
# Street Type                                                    RD
# Police District Number                                         5D
# Location                                        39.1581, -77.2788
# Name: 108379, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                    1314
# CR Number                                   17011244
# Dispatch Date / Time                             NaT
# Start_Date_Time                  2017-03-03 04:30:00
# End_Date_Time                    2017-03-03 05:00:00
# NIBRS Code                                       13A
# Victims                                            1
# Crime Name1                     Crime Against Person
# Crime Name2                       Aggravated Assault
# Crime Name3               ASSAULT - AGGRAVATED - GUN
# Police District Name                     TAKOMA PARK
# City                                              TP
# State                                            NaN
# Zip Code                                        <NA>
# Agency                                          TPPD
# Place                       Parking Lot - Commercial
# Sector                                             T
# Beat                                             8T3
# PRA                                              808
# Street Name                            NEW HAMPSHIRE
# Street Type                                      AVE
# Police District Number                          TPPD
# Location                           38.9756, -76.9939
# Name: 108402, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                                    2605
# CR Number                                                   17011964
# Dispatch Date / Time                                             NaT
# Start_Date_Time                                  2017-02-08 00:00:00
# End_Date_Time                                                    NaT
# NIBRS Code                                                       26B
# Victims                                                            1
# Crime Name1                                   Crime Against Property
# Crime Name2               Credit Card/Automatic Teller Machine Fraud
# Crime Name3                         FRAUD - ILLEGAL USE CREDIT CARDS
# Police District Name                                        BETHESDA
# City                                                        BETHESDA
# State                                                             MD
# Zip Code                                                        <NA>
# Agency                                                          MCPD
# Place                                                  Other/Unknown
# Sector                                                             E
# Beat                                                             2E2
# PRA                                                              059
# Street Name                                                MARYKNOLL
# Street Type                                                      AVE
# Police District Number                                            2D
# Location                                            38.9903, -77.139
# Name: 108413, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                            2301
# CR Number                                           17009064
# Dispatch Date / Time                                     NaT
# Start_Date_Time                          2017-02-18 13:30:00
# End_Date_Time                            2017-02-19 16:00:00
# NIBRS Code                                               23A
# Victims                                                    1
# Crime Name1                           Crime Against Property
# Crime Name2                                   Pocket/picking
# Crime Name3                         LARCENY - POCKET PICKING
# Police District Name                      MONTGOMERY VILLAGE
# City                                                      GA
# State                                                    NaN
# Zip Code                                                <NA>
# Agency                                                  MCPD
# Place                     Retail - Department/Discount Store
# Sector                                                     P
# Beat                                                     6P3
# PRA                                                      435
# Street Name                                      SHADY GROVE
# Street Type                                               RD
# Police District Number                                    6D
# Location                                   39.1133, -77.1865
# Name: 108431, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                            5404
# CR Number                                           17008809
# Dispatch Date / Time                                     NaT
# Start_Date_Time                          2017-02-18 04:50:00
# End_Date_Time                            2017-02-18 06:00:00
# NIBRS Code                                               90D
# Victims                                                    1
# Crime Name1                            Crime Against Society
# Crime Name2                      Driving Under the Influence
# Crime Name3               DRIVING UNDER THE INFLUENCE LIQUOR
# Police District Name                             TAKOMA PARK
# City                                                      TP
# State                                                    NaN
# Zip Code                                                <NA>
# Agency                                                  TPPD
# Place                                    Street - Commercial
# Sector                                                     T
# Beat                                                     8T2
# PRA                                                      805
# Street Name                                           FLOWER
# Street Type                                              AVE
# Police District Number                                  TPPD
# Location                                   38.9848, -76.9985
# Name: 108459, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                                  2902
# CR Number                                                 17010473
# Dispatch Date / Time                                           NaT
# Start_Date_Time                                2017-02-26 17:00:00
# End_Date_Time                                  2017-02-27 07:00:00
# NIBRS Code                                                     290
# Victims                                                          1
# Crime Name1                                 Crime Against Property
# Crime Name2               Destruction/Damage/Vandalism of Property
# Crime Name3                              DAMAGE PROPERTY - PRIVATE
# Police District Name                            MONTGOMERY VILLAGE
# City                                                  GAITHERSBURG
# State                                                           MD
# Zip Code                                                      <NA>
# Agency                                                        MCPD
# Place                                    Residence - Single Family
# Sector                                                           P
# Beat                                                           6P2
# PRA                                                            450
# Street Name                                              KENT OAKS
# Street Type                                                    WAY
# Police District Number                                          6D
# Location                                         39.1168, -77.2442
# Name: 108464, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                                 2699
# CR Number                                                17013329
# Dispatch Date / Time                                          NaT
# Start_Date_Time                               2016-10-31 09:40:00
# End_Date_Time                                 2016-11-01 20:00:00
# NIBRS Code                                                    26A
# Victims                                                         1
# Crime Name1                                Crime Against Property
# Crime Name2               False Pretenses/Swindle/Confidence Game
# Crime Name3                              FRAUD (DESCRIBE OFFENSE)
# Police District Name                                SILVER SPRING
# City                                                SILVER SPRING
# State                                                         NaN
# Zip Code                                                     <NA>
# Agency                                                       MCPD
# Place                                   Residence - Single Family
# Sector                                                          I
# Beat                                                          3I1
# PRA                                                           148
# Street Name                                             MILESTONE
# Street Type                                                    DR
# Police District Number                                         3D
# Location                                         39.0457, -76.992
# Name: 108466, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                                2204
# CR Number                                               17015880
# Dispatch Date / Time                                         NaT
# Start_Date_Time                              2017-03-28 20:40:00
# End_Date_Time                                                NaT
# NIBRS Code                                                   220
# Victims                                                        1
# Crime Name1                               Crime Against Property
# Crime Name2                       Burglary/Breaking and Entering
# Crime Name3               BURGLARY - NO FORCED ENTRY-RESIDENTIAL
# Police District Name                                 TAKOMA PARK
# City                                                          TP
# State                                                        NaN
# Zip Code                                                    <NA>
# Agency                                                      TPPD
# Place                                Residence - Apartment/Condo
# Sector                                                         T
# Beat                                                         8T2
# PRA                                                          803
# Street Name                                              HOUSTON
# Street Type                                                  AVE
# Police District Number                                      TPPD
# Location                                       38.9888, -77.0054
# Name: 108467, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                              1399
# CR Number                             17014010
# Dispatch Date / Time                       NaT
# Start_Date_Time            2017-03-19 00:48:00
# End_Date_Time                              NaT
# NIBRS Code                                 13B
# Victims                                      1
# Crime Name1               Crime Against Person
# Crime Name2                     Simple Assault
# Crime Name3               ASSAULT - 2ND DEGREE
# Police District Name               TAKOMA PARK
# City                                        TP
# State                                      NaN
# Zip Code                                  <NA>
# Agency                                    TPPD
# Place                      Parking Lot - Other
# Sector                                       T
# Beat                                       8T2
# PRA                                        803
# Street Name                             FLOWER
# Street Type                                AVE
# Police District Number                    TPPD
# Location                     38.9965, -77.0031
# Name: 108469, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )

# %%
import pandas as pd
import googlemaps
import time

# Set up Google Maps client with your API key
gmaps = googlemaps.Client(key='AIzaSyDSF-KKsdLnE1TQyj2ayORKehzCCIM5QUY')

# Abbreviation to full street type name mapping
street_type_mapping = {
    'Road': 'RD',
    'Avenue': 'AVE',
    'Street': 'ST',
    'Drive': 'DR',
    'Lane': 'LA',
    'Boulevard': 'BLV',
    'Court': 'CT',
    'Pike': 'PIK',
    'Way': 'WAY',
    'Place': 'PL',
    'Terrace': 'TER',
    'Circle': 'CIR',
    'Parkway': 'PKW',
    'Highway': 'HWY',
    'Alley': 'AL',
    'Square': 'SQ',
    'Mews': 'MEW',
    'Crescent': 'CRE',
    'Plaza': 'PLZ',
    'Overpass': 'OV',
    'Ramp': 'RMP',
    'Trail': 'TRL',
    'Center': 'CTR',
    'Run': 'RUN',
    'Draw': 'DRW',
    'Loop': 'LP',
    'Esplanade': 'ESP',
    'River': 'RVR',
    'Cove': 'COV',
    'Entrance': 'ENT',
    'End': 'END',
    'Farm': 'FAR',
    'Driveway':'DRW',
    'Overlook':'OVLK'
}

def update_street_type(row):
    # Check if 'Street Type' is missing or blank
    if pd.isna(row['Street Type']) or row['Street Type'].strip() == '':
        try:
            # Extract latitude and longitude from the location
            lat, lng = map(float, row['Location'].split(', '))
            # Get the address from Google Maps API
            results = gmaps.reverse_geocode((lat, lng))
            # Introduce a delay to avoid hitting rate limits
            time.sleep(0.1)  # 100 milliseconds delay

            # Extract the street type from the results
            for result in results:
                for component in result['address_components']:
                    if 'route' in component['types']:
                        # Split the long name to check for street type abbreviations
                        street_info = component['long_name'].split()
                        # Check if the last word in 'long_name' is a street type abbreviation
                        if street_info[-1] in street_type_mapping:
                            # Return the full street type name
                            return street_type_mapping[street_info[-1]]
                        else:
                            # Return the original street type if not an abbreviation
                            return street_info[-1]
        except Exception as e:
            print(f"Error processing row: {row}, Error: {e}")
            return None
    else:
        # Return the existing street type if it's already present
        return row['Street Type']

# Update the street types in the DataFrame
df_loc['Street Type'] = df_loc.apply(update_street_type, axis=1)
# Out:
# Error processing row: Offence Code                                                 2699
# CR Number                                               230052653
# Dispatch Date / Time                          2023-09-01 14:59:19
# Start_Date_Time                               2023-09-01 14:59:00
# End_Date_Time                                                 NaT
# NIBRS Code                                                    26A
# Victims                                                         1
# Crime Name1                                Crime Against Property
# Crime Name2               False Pretenses/Swindle/Confidence Game
# Crime Name3                              FRAUD (DESCRIBE OFFENSE)
# Police District Name                                    ROCKVILLE
# City                                                    ROCKVILLE
# State                                                          MD
# Zip Code                                                    20850
# Agency                                                       RCPD
# Place                                               Other/Unknown
# Sector                                                          A
# Beat                                                          1A1
# PRA                                                           258
# Street Name                                          NEW MARK ESP
# Street Type                                                   NaN
# Police District Number                                         1D
# Location                                        39.0765, -77.1552
# Name: 2895, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                                  2902
# CR Number                                                220042545
# Dispatch Date / Time                           2022-09-29 18:06:59
# Start_Date_Time                                2022-09-29 18:06:00
# End_Date_Time                                                  NaT
# NIBRS Code                                                     290
# Victims                                                          1
# Crime Name1                                 Crime Against Property
# Crime Name2               Destruction/Damage/Vandalism of Property
# Crime Name3                              DAMAGE PROPERTY - PRIVATE
# Police District Name                                     ROCKVILLE
# City                                                     ROCKVILLE
# State                                                           MD
# Zip Code                                                     20850
# Agency                                                        MCPD
# Place                                                  Auto Repair
# Sector                                                           A
# Beat                                                           1A3
# PRA                                                            283
# Street Name                                                PARK RD
# Street Type                                                    NaN
# Police District Number                                          1D
# Location                                         39.0855, -77.1466
# Name: 5620, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                    2303
# CR Number                                  230019679
# Dispatch Date / Time             2023-04-25 08:57:32
# Start_Date_Time                  2023-04-25 08:57:00
# End_Date_Time                    2023-04-25 08:57:00
# NIBRS Code                                       23C
# Victims                                            1
# Crime Name1                   Crime Against Property
# Crime Name2                              Shoplifting
# Crime Name3                    LARCENY - SHOPLIFTING
# Police District Name                       ROCKVILLE
# City                                       ROCKVILLE
# State                                             MD
# Zip Code                                       20850
# Agency                                          RCPD
# Place                     Liquor Store - Beer & Wine
# Sector                                             A
# Beat                                             1A3
# PRA                                              283
# Street Name                                  PARK RD
# Street Type                                      NaN
# Police District Number                            1D
# Location                           39.0855, -77.1466
# Name: 12277, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                             2202
# CR Number                                           230022787
# Dispatch Date / Time                      2023-05-12 11:59:14
# Start_Date_Time                           2023-05-12 11:10:00
# End_Date_Time                             2023-05-12 11:13:00
# NIBRS Code                                                220
# Victims                                                     1
# Crime Name1                            Crime Against Property
# Crime Name2                    Burglary/Breaking and Entering
# Crime Name3               BURGLARY - FORCED ENTRY-RESIDENTIAL
# Police District Name                                ROCKVILLE
# City                                                ROCKVILLE
# State                                                      MD
# Zip Code                                                20850
# Agency                                                   RCPD
# Place                               Residence - Single Family
# Sector                                                      A
# Beat                                                      1A3
# PRA                                                       284
# Street Name                                           PARK RD
# Street Type                                               NaN
# Police District Number                                     1D
# Location                                    39.0855, -77.1466
# Name: 12491, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                              1399
# CR Number                            230024791
# Dispatch Date / Time       2023-05-23 18:56:01
# Start_Date_Time            2023-05-23 18:56:00
# End_Date_Time              2023-05-23 19:30:00
# NIBRS Code                                 13B
# Victims                                      1
# Crime Name1               Crime Against Person
# Crime Name2                     Simple Assault
# Crime Name3               ASSAULT - 2ND DEGREE
# Police District Name                 ROCKVILLE
# City                                 ROCKVILLE
# State                                       MD
# Zip Code                                 20850
# Agency                                    RCPD
# Place                        Convenience Store
# Sector                                       A
# Beat                                       1A3
# PRA                                        283
# Street Name                            PARK RD
# Street Type                                NaN
# Police District Number                      1D
# Location                     39.0855, -77.1466
# Name: 13042, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                2303
# CR Number                              230024791
# Dispatch Date / Time         2023-05-23 18:56:01
# Start_Date_Time              2023-05-23 18:56:00
# End_Date_Time                2023-05-23 19:30:00
# NIBRS Code                                   23C
# Victims                                        1
# Crime Name1               Crime Against Property
# Crime Name2                          Shoplifting
# Crime Name3                LARCENY - SHOPLIFTING
# Police District Name                   ROCKVILLE
# City                                   ROCKVILLE
# State                                         MD
# Zip Code                                   20850
# Agency                                      RCPD
# Place                          Convenience Store
# Sector                                         A
# Beat                                         1A3
# PRA                                          283
# Street Name                              PARK RD
# Street Type                                  NaN
# Police District Number                        1D
# Location                       39.0855, -77.1466
# Name: 13043, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                                2204
# CR Number                                              220049430
# Dispatch Date / Time                         2022-11-09 07:42:00
# Start_Date_Time                              2022-11-09 06:00:00
# End_Date_Time                                2022-11-09 07:45:00
# NIBRS Code                                                   220
# Victims                                                        1
# Crime Name1                               Crime Against Property
# Crime Name2                       Burglary/Breaking and Entering
# Crime Name3               BURGLARY - NO FORCED ENTRY-RESIDENTIAL
# Police District Name                                   ROCKVILLE
# City                                                   ROCKVILLE
# State                                                         MD
# Zip Code                                                   20850
# Agency                                                      RCPD
# Place                                  Residence - Single Family
# Sector                                                         A
# Beat                                                         1A3
# PRA                                                          283
# Street Name                                              PARK RD
# Street Type                                                  NaN
# Police District Number                                        1D
# Location                                       39.0864, -77.1443
# Name: 13200, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                                  2902
# CR Number                                                230025667
# Dispatch Date / Time                           2023-05-28 21:55:16
# Start_Date_Time                                2023-05-28 21:55:00
# End_Date_Time                                  2023-05-28 21:55:00
# NIBRS Code                                                     290
# Victims                                                          1
# Crime Name1                                 Crime Against Property
# Crime Name2               Destruction/Damage/Vandalism of Property
# Crime Name3                              DAMAGE PROPERTY - PRIVATE
# Police District Name                                     ROCKVILLE
# City                                                     ROCKVILLE
# State                                                           MD
# Zip Code                                                     20850
# Agency                                                        RCPD
# Place                                            Residence - Other
# Sector                                                           A
# Beat                                                           1A1
# PRA                                                            258
# Street Name                                           NEW MARK ESP
# Street Type                                                    NaN
# Police District Number                                          1D
# Location                                         39.0779, -77.1552
# Name: 13332, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                            5404
# CR Number                                          220050935
# Dispatch Date / Time                     2022-11-17 19:41:02
# Start_Date_Time                          2022-11-17 19:41:00
# End_Date_Time                                            NaT
# NIBRS Code                                               90D
# Victims                                                    1
# Crime Name1                            Crime Against Society
# Crime Name2                      Driving Under the Influence
# Crime Name3               DRIVING UNDER THE INFLUENCE LIQUOR
# Police District Name                      MONTGOMERY VILLAGE
# City                                            GAITHERSBURG
# State                                                     MD
# Zip Code                                               20877
# Agency                                                  MCPD
# Place                                    Street - In vehicle
# Sector                                                     P
# Beat                                                     6P3
# PRA                                                      418
# Street Name                                      RAILROAD ST
# Street Type                                              NaN
# Police District Number                                    6D
# Location                                   39.1343, -77.1759
# Name: 15574, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                                   2205
# CR Number                                                 230028561
# Dispatch Date / Time                            2023-06-14 01:15:48
# Start_Date_Time                                 2023-06-14 01:15:00
# End_Date_Time                                                   NaT
# NIBRS Code                                                      220
# Victims                                                           1
# Crime Name1                                  Crime Against Property
# Crime Name2                          Burglary/Breaking and Entering
# Crime Name3               BURGLARY - NO FORCED ENTRY-NONRESIDENTIAL
# Police District Name                                       BETHESDA
# City                                                       BETHESDA
# State                                                            MD
# Zip Code                                                      20814
# Agency                                                         MCPD
# Place                                 School - Elementary/Secondary
# Sector                                                            E
# Beat                                                            2E2
# PRA                                                             071
# Street Name                                               FOREST RD
# Street Type                                                     NaN
# Police District Number                                           2D
# Location                                          39.0127, -77.1134
# Name: 16982, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                    2399
# CR Number                                  230063464
# Dispatch Date / Time             2023-10-30 18:16:04
# Start_Date_Time                  2023-10-27 00:00:00
# End_Date_Time                                    NaT
# NIBRS Code                                       23H
# Victims                                            1
# Crime Name1                   Crime Against Property
# Crime Name2                        All other Larceny
# Crime Name3               LARCENY (DESCRIBE OFFENSE)
# Police District Name                        BETHESDA
# City                                     CHEVY CHASE
# State                                             MD
# Zip Code                                       20815
# Agency                                          MCPD
# Place                                  Other/Unknown
# Sector                                             D
# Beat                                             2D3
# PRA                                              077
# Street Name                           KENILWORTH DRW
# Street Type                                      NaN
# Police District Number                            2D
# Location                            39.002, -77.0751
# Name: 17678, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                2610
# CR Number                              230031664
# Dispatch Date / Time         2023-07-03 09:28:26
# Start_Date_Time              2023-02-16 07:00:00
# End_Date_Time                2023-05-09 07:00:00
# NIBRS Code                                   26F
# Victims                                        1
# Crime Name1               Crime Against Property
# Crime Name2                       Identity Theft
# Crime Name3                       IDENTITY THEFT
# Police District Name                    BETHESDA
# City                                 CHEVY CHASE
# State                                         MD
# Zip Code                                   20815
# Agency                                      MCPD
# Place                              Other/Unknown
# Sector                                         D
# Beat                                         2D3
# PRA                                          077
# Street Name                       KENILWORTH DRW
# Street Type                                  NaN
# Police District Number                        2D
# Location                       39.0017, -77.0728
# Name: 21525, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                       1399
# CR Number                                     230060144
# Dispatch Date / Time                2023-10-12 17:39:24
# Start_Date_Time                     2023-10-12 17:39:00
# End_Date_Time                       2023-10-12 18:00:00
# NIBRS Code                                          13B
# Victims                                               1
# Crime Name1                        Crime Against Person
# Crime Name2                              Simple Assault
# Crime Name3                        ASSAULT - 2ND DEGREE
# Police District Name                           BETHESDA
# City                                           BETHESDA
# State                                                MD
# Zip Code                                          20814
# Agency                                             MCPD
# Place                     School - Elementary/Secondary
# Sector                                                E
# Beat                                                2E2
# PRA                                                 071
# Street Name                                   FOREST RD
# Street Type                                         NaN
# Police District Number                               2D
# Location                              39.0128, -77.1134
# Name: 21713, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                                  2902
# CR Number                                                230061982
# Dispatch Date / Time                           2023-10-22 14:47:04
# Start_Date_Time                                2023-10-22 13:30:00
# End_Date_Time                                  2023-10-22 11:00:00
# NIBRS Code                                                     290
# Victims                                                          1
# Crime Name1                                 Crime Against Property
# Crime Name2               Destruction/Damage/Vandalism of Property
# Crime Name3                              DAMAGE PROPERTY - PRIVATE
# Police District Name                                      BETHESDA
# City                                                   CHEVY CHASE
# State                                                           MD
# Zip Code                                                     20815
# Agency                                                        MCPD
# Place                                         Street - Residential
# Sector                                                           D
# Beat                                                           2D3
# PRA                                                            077
# Street Name                                            STEWART DRW
# Street Type                                                    NaN
# Police District Number                                          2D
# Location                                         39.0004, -77.0727
# Name: 26415, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                                  2999
# CR Number                                                230053606
# Dispatch Date / Time                           2023-09-07 10:11:38
# Start_Date_Time                                2023-08-04 00:00:00
# End_Date_Time                                  2023-08-05 23:59:00
# NIBRS Code                                                     290
# Victims                                                          1
# Crime Name1                                 Crime Against Property
# Crime Name2               Destruction/Damage/Vandalism of Property
# Crime Name3                     DAMAGE PROPERTY (DESCRIBE OFFENSE)
# Police District Name                                     ROCKVILLE
# City                                                     ROCKVILLE
# State                                                           MD
# Zip Code                                                     20850
# Agency                                                        RCPD
# Place                                             Residence - Yard
# Sector                                                           A
# Beat                                                           1A1
# PRA                                                            258
# Street Name                                           NEW MARK ESP
# Street Type                                                    NaN
# Police District Number                                          1D
# Location                                         39.0779, -77.1551
# Name: 30881, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                   4199
# CR Number                                 170501322
# Dispatch Date / Time            2017-04-09 23:54:07
# Start_Date_Time                 2017-04-09 23:54:00
# End_Date_Time                   2017-04-09 23:54:00
# NIBRS Code                                      90G
# Victims                                           1
# Crime Name1                   Crime Against Society
# Crime Name2                   Liquor Law Violations
# Crime Name3               LIQUOR (DESCRIBE OFFENSE)
# Police District Name                  SILVER SPRING
# City                                  SILVER SPRING
# State                                            MD
# Zip Code                                       <NA>
# Agency                                         MCPD
# Place                           Street - Commercial
# Sector                                            G
# Beat                                            3G1
# PRA                                             094
# Street Name                                  THAYER
# Street Type                                     NaN
# Police District Number                           3D
# Location                          38.9936, -77.0102
# Name: 31196, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                     3562
# CR Number                                   170504880
# Dispatch Date / Time              2017-04-29 02:10:23
# Start_Date_Time                   2017-04-29 02:10:00
# End_Date_Time                     2017-04-29 03:00:00
# NIBRS Code                                        35A
# Victims                                             1
# Crime Name1                     Crime Against Society
# Crime Name2                  Drug/Narcotic Violations
# Crime Name3               DRUGS - MARIJUANA - POSSESS
# Police District Name                        ROCKVILLE
# City                                        ROCKVILLE
# State                                              MD
# Zip Code                                         <NA>
# Agency                                           RCPD
# Place                             Street - In vehicle
# Sector                                              A
# Beat                                              1A4
# PRA                                               280
# Street Name                                 FREDERICK
# Street Type                                       NaN
# Police District Number                             1D
# Location                            39.0591, -77.1162
# Name: 31476, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                            5404
# CR Number                                          170502411
# Dispatch Date / Time                     2017-04-16 02:55:33
# Start_Date_Time                          2017-04-16 02:56:00
# End_Date_Time                                            NaT
# NIBRS Code                                               90D
# Victims                                                    1
# Crime Name1                            Crime Against Society
# Crime Name2                      Driving Under the Influence
# Crime Name3               DRIVING UNDER THE INFLUENCE LIQUOR
# Police District Name                           SILVER SPRING
# City                                           SILVER SPRING
# State                                                     MD
# Zip Code                                                <NA>
# Agency                                                  MCPD
# Place                                    Street - In vehicle
# Sector                                                     I
# Beat                                                     3I1
# PRA                                                      519
# Street Name                                    NEW HAMPSHIRE
# Street Type                                              NaN
# Police District Number                                    3D
# Location                                   38.9799, -76.9899
# Name: 31613, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                               4104
# CR Number                             170504880
# Dispatch Date / Time        2017-04-29 02:10:23
# Start_Date_Time             2017-04-29 02:10:00
# End_Date_Time               2017-04-29 03:00:00
# NIBRS Code                                  90G
# Victims                                       1
# Crime Name1               Crime Against Society
# Crime Name2               Liquor Law Violations
# Crime Name3                    LIQUOR - POSSESS
# Police District Name                  ROCKVILLE
# City                                  ROCKVILLE
# State                                        MD
# Zip Code                                   <NA>
# Agency                                     RCPD
# Place                       Street - In vehicle
# Sector                                        A
# Beat                                        1A4
# PRA                                         280
# Street Name                           FREDERICK
# Street Type                                 NaN
# Police District Number                       1D
# Location                      39.0591, -77.1162
# Name: 31841, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                            5404
# CR Number                                          230070837
# Dispatch Date / Time                     2023-12-09 23:28:41
# Start_Date_Time                          2023-12-09 23:28:00
# End_Date_Time                                            NaT
# NIBRS Code                                               90D
# Victims                                                    1
# Crime Name1                            Crime Against Society
# Crime Name2                      Driving Under the Influence
# Crime Name3               DRIVING UNDER THE INFLUENCE LIQUOR
# Police District Name                      MONTGOMERY VILLAGE
# City                                        WASHINGTON GROVE
# State                                                     MD
# Zip Code                                               20880
# Agency                                                   GPD
# Place                                    Street - In vehicle
# Sector                                                     P
# Beat                                                     6P3
# PRA                                                      418
# Street Name                                      RAILROAD ST
# Street Type                                              NaN
# Police District Number                                    6D
# Location                                   39.1343, -77.1759
# Name: 31890, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                              1399
# CR Number                            170503825
# Dispatch Date / Time       2017-04-24 02:21:25
# Start_Date_Time            2017-04-23 20:30:00
# End_Date_Time              2017-04-23 20:35:00
# NIBRS Code                                 13B
# Victims                                      1
# Crime Name1               Crime Against Person
# Crime Name2                     Simple Assault
# Crime Name3               ASSAULT - 2ND DEGREE
# Police District Name             SILVER SPRING
# City                             SILVER SPRING
# State                                       MD
# Zip Code                                  <NA>
# Agency                                    MCPD
# Place                     Street - Residential
# Sector                                       H
# Beat                                       3H1
# PRA                                        131
# Street Name                               11TH
# Street Type                                NaN
# Police District Number                      3D
# Location                     38.9951, -76.9902
# Name: 31988, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                              1399
# CR Number                            170504743
# Dispatch Date / Time       2017-04-28 15:05:12
# Start_Date_Time            2017-04-28 15:05:00
# End_Date_Time                              NaT
# NIBRS Code                                 13B
# Victims                                      1
# Crime Name1               Crime Against Person
# Crime Name2                     Simple Assault
# Crime Name3               ASSAULT - 2ND DEGREE
# Police District Name                GERMANTOWN
# City                                GERMANTOWN
# State                                       MD
# Zip Code                                  <NA>
# Agency                                    MCPD
# Place                           Street - Other
# Sector                                       N
# Beat                                       5N2
# PRA                                        448
# Street Name                       GREAT SENECA
# Street Type                                NaN
# Police District Number                      5D
# Location                     39.1281, -77.2372
# Name: 32310, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                                  2902
# CR Number                                                170504743
# Dispatch Date / Time                           2017-04-28 15:05:12
# Start_Date_Time                                2017-04-28 15:05:00
# End_Date_Time                                                  NaT
# NIBRS Code                                                     290
# Victims                                                          1
# Crime Name1                                 Crime Against Property
# Crime Name2               Destruction/Damage/Vandalism of Property
# Crime Name3                              DAMAGE PROPERTY - PRIVATE
# Police District Name                                    GERMANTOWN
# City                                                    GERMANTOWN
# State                                                           MD
# Zip Code                                                      <NA>
# Agency                                                        MCPD
# Place                                          Street - In vehicle
# Sector                                                           N
# Beat                                                           5N2
# PRA                                                            448
# Street Name                                           GREAT SENECA
# Street Type                                                    NaN
# Police District Number                                          5D
# Location                                         39.1281, -77.2372
# Name: 32311, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                     3562
# CR Number                                   170504621
# Dispatch Date / Time              2017-04-27 23:20:36
# Start_Date_Time                   2017-04-27 23:27:00
# End_Date_Time                     2017-04-27 23:27:00
# NIBRS Code                                        35A
# Victims                                             1
# Crime Name1                     Crime Against Society
# Crime Name2                  Drug/Narcotic Violations
# Crime Name3               DRUGS - MARIJUANA - POSSESS
# Police District Name               MONTGOMERY VILLAGE
# City                                     GAITHERSBURG
# State                                              MD
# Zip Code                                         <NA>
# Agency                                           MCPD
# Place                             Street - In vehicle
# Sector                                              P
# Beat                                              6P1
# PRA                                               549
# Street Name                             WASHINGTONIAN
# Street Type                                       NaN
# Police District Number                             6D
# Location                            39.1171, -77.2015
# Name: 32534, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                            5404
# CR Number                                          170505796
# Dispatch Date / Time                     2017-05-04 01:18:27
# Start_Date_Time                          2017-05-04 01:18:00
# End_Date_Time                                            NaT
# NIBRS Code                                               90D
# Victims                                                    1
# Crime Name1                            Crime Against Society
# Crime Name2                      Driving Under the Influence
# Crime Name3               DRIVING UNDER THE INFLUENCE LIQUOR
# Police District Name                      MONTGOMERY VILLAGE
# City                                            GAITHERSBURG
# State                                                     MD
# Zip Code                                                <NA>
# Agency                                                   GPD
# Place                                    Street - In vehicle
# Sector                                                     P
# Beat                                                     6P2
# PRA                                                      450
# Street Name                                      CHESTERTOWN
# Street Type                                              NaN
# Police District Number                                    6D
# Location                                   39.1241, -77.2459
# Name: 32675, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                                 2602
# CR Number                                               230067443
# Dispatch Date / Time                          2023-11-20 15:23:04
# Start_Date_Time                               2023-11-15 00:00:00
# End_Date_Time                                 2023-11-20 15:00:00
# NIBRS Code                                                    26A
# Victims                                                         1
# Crime Name1                                Crime Against Property
# Crime Name2               False Pretenses/Swindle/Confidence Game
# Crime Name3                                       FRAUD - SWINDLE
# Police District Name                           MONTGOMERY VILLAGE
# City                                                      DERWOOD
# State                                                          MD
# Zip Code                                                    20855
# Agency                                                       MCPD
# Place                                                  Cyberspace
# Sector                                                          R
# Beat                                                          6R3
# PRA                                                           665
# Street Name                                              PILGRIMS
# Street Type                                                   NaN
# Police District Number                                         6D
# Location                                        39.1388, -77.1339
# Name: 32702, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                       9003
# CR Number                                     230008679
# Dispatch Date / Time                                NaT
# Start_Date_Time                     2023-02-04 00:00:00
# End_Date_Time                                       NaT
# NIBRS Code                                          11C
# Victims                                               1
# Crime Name1                        Crime Against Person
# Crime Name2               Sexual Assault With An Object
# Crime Name3                SEX ASSAULT - WITH AN OBJECT
# Police District Name                          ROCKVILLE
# City                                          ROCKVILLE
# State                                                MD
# Zip Code                                          20850
# Agency                                             MCPD
# Place                         Residence - Single Family
# Sector                                                A
# Beat                                                1A3
# PRA                                                 286
# Street Name                                     PARK RD
# Street Type                                         NaN
# Police District Number                               1D
# Location                                39.0869, -77.14
# Name: 37504, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                  2305
# CR Number                                230054377
# Dispatch Date / Time                           NaT
# Start_Date_Time                2023-09-11 20:45:00
# End_Date_Time                  2023-09-12 06:35:00
# NIBRS Code                                     23F
# Victims                                          1
# Crime Name1                 Crime Against Property
# Crime Name2               Theft From Motor Vehicle
# Crime Name3                    LARCENY - FROM AUTO
# Police District Name                      BETHESDA
# City                                   CHEVY CHASE
# State                                           MD
# Zip Code                                     20815
# Agency                                        MCPD
# Place                         Street - Residential
# Sector                                           D
# Beat                                           2D3
# PRA                                            076
# Street Name                           MONTROSE DRW
# Street Type                                    NaN
# Police District Number                          2D
# Location                         39.0017, -77.0773
# Name: 38592, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                               9105
# CR Number                             240035028
# Dispatch Date / Time        2024-07-24 20:53:35
# Start_Date_Time             2024-07-04 20:53:00
# End_Date_Time               2024-07-06 21:00:00
# NIBRS Code                                  90Z
# Victims                                       1
# Crime Name1               Crime Against Society
# Crime Name2                  All Other Offenses
# Crime Name3                       LOST PROPERTY
# Police District Name                  ROCKVILLE
# City                                  ROCKVILLE
# State                                       NaN
# Zip Code                                  20850
# Agency                                     RCPD
# Place                       Street - In vehicle
# Sector                                        A
# Beat                                        1A1
# PRA                                         258
# Street Name                        NEW MARK ESP
# Street Type                                 NaN
# Police District Number                       1D
# Location                      39.0764, -77.1557
# Name: 43917, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                            5404
# CR Number                                          240030681
# Dispatch Date / Time                                     NaT
# Start_Date_Time                          2024-06-29 00:48:00
# End_Date_Time                            2024-06-29 00:48:00
# NIBRS Code                                               90D
# Victims                                                    1
# Crime Name1                            Crime Against Society
# Crime Name2                      Driving Under the Influence
# Crime Name3               DRIVING UNDER THE INFLUENCE LIQUOR
# Police District Name                               ROCKVILLE
# City                                               ROCKVILLE
# State                                                     MD
# Zip Code                                               20850
# Agency                                                  RCPD
# Place                                    Street - Commercial
# Sector                                                     A
# Beat                                                     1A3
# PRA                                                      283
# Street Name                                          PARK RD
# Street Type                                              NaN
# Police District Number                                    1D
# Location                                   39.0869, -77.1406
# Name: 44611, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                    2404
# CR Number                                  240004440
# Dispatch Date / Time             2024-01-28 11:49:26
# Start_Date_Time                  2024-01-28 22:20:00
# End_Date_Time                    2024-01-28 12:00:00
# NIBRS Code                                       240
# Victims                                            1
# Crime Name1                   Crime Against Property
# Crime Name2                      Motor Vehicle Theft
# Crime Name3               AUTO THEFT - VEHICLE THEFT
# Police District Name                       ROCKVILLE
# City                                       ROCKVILLE
# State                                             MD
# Zip Code                                       20850
# ...
# State                                        MD
# Zip Code                                  20854
# Agency                                     MCPD
# Place                                      Park
# Sector                                        E
# Beat                                        2E4
# PRA                                         213
# Street Name                       POTOMAC RIVER
# Street Type                                 NaN
# Police District Number                       2D
# Location                      38.9797, -77.2382
# Name: 382052, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                                5309
# CR Number                                              200042287
# Dispatch Date / Time                         2020-10-26 19:45:58
# Start_Date_Time                              2020-10-20 20:00:00
# End_Date_Time                                2020-10-26 19:00:00
# NIBRS Code                                                   90Z
# Victims                                                        1
# Crime Name1                                Crime Against Society
# Crime Name2                                   All Other Offenses
# Crime Name3               PUBLIC PEACE - HARASSING COMMUNICATION
# Police District Name                                    BETHESDA
# City                                                 CHEVY CHASE
# State                                                         MD
# Zip Code                                                   20815
# Agency                                                      MCPD
# Place                                  Residence - Single Family
# Sector                                                         D
# Beat                                                         2D3
# PRA                                                          077
# Street Name                                       KENILWORTH DRW
# Street Type                                                  NaN
# Police District Number                                        2D
# Location                                       39.0017, -77.0714
# Name: 388142, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                       9108
# CR Number                                     200040746
# Dispatch Date / Time                2020-10-15 23:02:42
# Start_Date_Time                     2020-10-15 23:02:00
# End_Date_Time                                       NaT
# NIBRS Code                                          90Z
# Victims                                               1
# Crime Name1                       Crime Against Society
# Crime Name2                          All Other Offenses
# Crime Name3               RECOVERED PROPERTY - MONT CO.
# Police District Name                           BETHESDA
# City                                        CHEVY CHASE
# State                                                MD
# Zip Code                                          20815
# Agency                                             MCPD
# Place                         Residence - Single Family
# Sector                                                D
# Beat                                                2D3
# PRA                                                 077
# Street Name                                  HUSTED DRW
# Street Type                                         NaN
# Police District Number                               2D
# Location                                39.0042, -77.07
# Name: 391464, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                   9101
# CR Number                                 210026513
# Dispatch Date / Time            2021-07-10 09:03:36
# Start_Date_Time                 2021-07-10 09:03:00
# End_Date_Time                   2021-07-10 09:16:00
# NIBRS Code                                      90Z
# Victims                                           1
# Crime Name1                   Crime Against Society
# Crime Name2                      All Other Offenses
# Crime Name3                            SUDDEN DEATH
# Police District Name                       BETHESDA
# City                                    CHEVY CHASE
# State                                            MD
# Zip Code                                      20815
# Agency                                         MCPD
# Place                     Residence - Single Family
# Sector                                            D
# Beat                                            2D3
# PRA                                             077
# Street Name                              HUSTED DRW
# Street Type                                     NaN
# Police District Number                           2D
# Location                            39.0042, -77.07
# Name: 395108, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                             9113
# CR Number                                           210030333
# Dispatch Date / Time                      2021-08-04 20:35:12
# Start_Date_Time                           2021-08-04 20:35:00
# End_Date_Time                                             NaT
# NIBRS Code                                                90Z
# Victims                                                     1
# Crime Name1                             Crime Against Society
# Crime Name2                                All Other Offenses
# Crime Name3               MENTAL ILLNESS - EMERGENCY PETITION
# Police District Name                       MONTGOMERY VILLAGE
# City                                             GAITHERSBURG
# State                                                      MD
# Zip Code                                                20877
# Agency                                                    GPD
# Place                                     Street - Commercial
# Sector                                                      P
# Beat                                                      6P3
# PRA                                                       419
# Street Name                                       RAILROAD ST
# Street Type                                               NaN
# Police District Number                                     6D
# Location                                    39.1343, -77.1759
# Name: 396795, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                               9199
# CR Number                             220031921
# Dispatch Date / Time        2022-07-24 21:20:45
# Start_Date_Time             2022-07-24 21:15:00
# End_Date_Time               2022-07-24 21:25:00
# NIBRS Code                                  90Z
# Victims                                       1
# Crime Name1               Crime Against Society
# Crime Name2                  All Other Offenses
# Crime Name3                  POLICE INFORMATION
# Police District Name                  ROCKVILLE
# City                                  ROCKVILLE
# State                                        MD
# Zip Code                                  20850
# Agency                                     RCPD
# Place                                      Park
# Sector                                        A
# Beat                                        1A1
# PRA                                         258
# Street Name                        NEW MARK ESP
# Street Type                                 NaN
# Police District Number                       1D
# Location                      39.0779, -77.1552
# Name: 401006, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                             9113
# CR Number                                           220023062
# Dispatch Date / Time                      2022-05-30 03:10:52
# Start_Date_Time                           2022-05-30 03:10:00
# End_Date_Time                             2022-05-30 03:40:00
# NIBRS Code                                                90Z
# Victims                                                     1
# Crime Name1                             Crime Against Society
# Crime Name2                                All Other Offenses
# Crime Name3               MENTAL ILLNESS - EMERGENCY PETITION
# Police District Name                                ROCKVILLE
# City                                                ROCKVILLE
# State                                                      MD
# Zip Code                                                20850
# Agency                                                   RCPD
# Place                             Residence -Townhouse/Duplex
# Sector                                                      A
# Beat                                                      1A1
# PRA                                                       258
# Street Name                                      NEW MARK ESP
# Street Type                                               NaN
# Police District Number                                     1D
# Location                                     39.0761, -77.158
# Name: 403965, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                   9199
# CR Number                                 230024620
# Dispatch Date / Time            2023-05-22 20:15:16
# Start_Date_Time                 2022-09-27 20:15:00
# End_Date_Time                   2023-05-22 20:14:00
# NIBRS Code                                      90Z
# Victims                                           1
# Crime Name1                   Crime Against Society
# Crime Name2                      All Other Offenses
# Crime Name3                      POLICE INFORMATION
# Police District Name                      ROCKVILLE
# City                                      ROCKVILLE
# State                                            MD
# Zip Code                                      20850
# Agency                                         RCPD
# Place                     Residence - Single Family
# Sector                                            A
# Beat                                            1A1
# PRA                                             258
# Street Name                            NEW MARK ESP
# Street Type                                     NaN
# Police District Number                           1D
# Location                          39.0765, -77.1552
# Name: 405722, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                     9101
# CR Number                                   220046600
# Dispatch Date / Time              2022-10-24 10:25:31
# Start_Date_Time                   2022-10-24 10:25:00
# End_Date_Time                     2022-10-24 23:00:00
# NIBRS Code                                        90Z
# Victims                                             1
# Crime Name1                     Crime Against Society
# Crime Name2                        All Other Offenses
# Crime Name3                              SUDDEN DEATH
# Police District Name                        ROCKVILLE
# City                                        ROCKVILLE
# State                                              MD
# Zip Code                                        20850
# Agency                                           RCPD
# Place                     Residence -Townhouse/Duplex
# Sector                                              A
# Beat                                              1A1
# PRA                                               258
# Street Name                              NEW MARK ESP
# Street Type                                       NaN
# Police District Number                             1D
# Location                             39.0761, -77.158
# Name: 406572, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                                       9106
# CR Number                                     220045858
# Dispatch Date / Time                2022-10-19 11:43:42
# Start_Date_Time                     2022-10-18 06:12:00
# End_Date_Time                                       NaT
# NIBRS Code                                          90Z
# Victims                                               1
# Crime Name1                       Crime Against Society
# Crime Name2                          All Other Offenses
# Crime Name3                              MENTAL ILLNESS
# Police District Name                           BETHESDA
# City                                           BETHESDA
# State                                                MD
# Zip Code                                          20814
# Agency                                             MCPD
# Place                     School - Elementary/Secondary
# Sector                                                E
# Beat                                                2E2
# PRA                                                 071
# Street Name                                   FOREST RD
# Street Type                                         NaN
# Police District Number                               2D
# Location                              39.0127, -77.1134
# Name: 406684, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )
# Error processing row: Offence Code                               9199
# CR Number                             220048241
# Dispatch Date / Time        2022-11-02 15:24:57
# Start_Date_Time             2022-11-02 15:24:00
# End_Date_Time               2022-11-02 15:24:00
# NIBRS Code                                  90Z
# Victims                                       1
# Crime Name1               Crime Against Society
# Crime Name2                  All Other Offenses
# Crime Name3                  POLICE INFORMATION
# Police District Name                  ROCKVILLE
# City                                  ROCKVILLE
# State                                        MD
# Zip Code                                  20850
# Agency                                     RCPD
# Place                      Street - Residential
# Sector                                        A
# Beat                                        1A1
# PRA                                         258
# Street Name                        NEW MARK ESP
# Street Type                                 NaN
# Police District Number                       1D
# Location                      39.0764, -77.1557
# Name: 411082, dtype: object, Error: REQUEST_DENIED (This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console. )

# %%
df_loc['Street Type'].value_counts()
# Out:
# Street Type
# RD     105604
# AVE     88362
# DR      71023
# ST      25725
# BLV     23410
# LA      22335
# CT      18975
# WAY     11954
# TER     10875
# PIK     10825
# CIR     10538
# PL      10246
# HWY      4152
# PKW      3733
# SQ        190
# RMP       144
# CTR       126
# PLZ       126
# MEW        52
# CRE        44
# TRL        34
# AL         32
# RUN        31
# OV         27
# LP         27
# DRW         9
# ESP         8
# ENT         7
# RVR         7
# COV         4
# FAR         1
# LN          1
# END         1
# CLS         1
# BRG         1
# Name: count, dtype: int64

# %%
# Drop rows where 'Street Type' matches any of the specified values
df_loc = df_loc[~((df_loc['Street Type'] == '650') |
                                (df_loc['Street Type'] == '29') |
                                (df_loc['Street Type'] == '193') |
                                (df_loc['Street Type'] == '97') |
                                (df_loc['Street Type'] == '195') |
                                (df_loc['Street Type'] == 'A'))]

# %%
df_loc['Street Type'].value_counts()
# Out:
# Street Type
# RD     105604
# AVE     88362
# DR      71023
# ST      25725
# BLV     23410
# LA      22335
# CT      18975
# WAY     11954
# TER     10875
# PIK     10825
# CIR     10538
# PL      10246
# HWY      4152
# PKW      3733
# SQ        190
# RMP       144
# CTR       126
# PLZ       126
# MEW        52
# CRE        44
# TRL        34
# AL         32
# RUN        31
# OV         27
# LP         27
# DRW         9
# ESP         8
# ENT         7
# RVR         7
# COV         4
# FAR         1
# LN          1
# END         1
# CLS         1
# BRG         1
# Name: count, dtype: int64

# %%
# Create a mask where all three crime name columns are missing
missing_all_crime_names = df_loc['Crime Name1'].isna() & df_loc['Crime Name2'].isna() & df_loc['Crime Name3'].isna()

# Identify the NIBRS Codes where all crime names are missing
nibrs_codes_with_missing_crime_names = df_loc.loc[missing_all_crime_names, 'NIBRS Code']

# Filter the DataFrame using this mask
missing_data = df_loc[missing_all_crime_names]

# Group by 'NIBRS Code' and count the occurrences of missing values
missing_counts = missing_data.groupby('NIBRS Code').size().reset_index(name='Missing Count')

# Filter the DataFrame for these NIBRS Codes
filtered_data = df_loc[df_loc['NIBRS Code'].isin(nibrs_codes_with_missing_crime_names)]

# Group by 'NIBRS Code' and aggregate the unique values in crime names
crime_name_values = filtered_data.groupby('NIBRS Code').agg({
    'Crime Name1': pd.Series.unique,
    'Crime Name2': pd.Series.unique,
    'Crime Name3': pd.Series.unique
}).reset_index()

# Merge the two dataframes
merged_data = pd.merge(missing_counts, crime_name_values, on='NIBRS Code')

# Display the result in a tabular format using tabulate
print(tabulate(merged_data, headers='keys', tablefmt='pretty'))
# Out:
# +---------------+------------+-------------+-------------+-------------+
# | Missing Count | NIBRS Code | Crime Name1 | Crime Name2 | Crime Name3 |
# +---------------+------------+-------------+-------------+-------------+
# +---------------+------------+-------------+-------------+-------------+

# %%
def update_and_clean_crime_data(df):
    # Define the updates in a structured format
    updates = {
        '26G': {
            'Crime Name1': 'Crime Against Property',
            'Crime Name2': 'Hacking/Computer Invasion',
            'Crime Name3': 'HACKING/COMPUTER INVASION'
        },
        '35A': {
            'Crime Name1': 'Crime Against Property',
            'Crime Name2': 'Drug/Narcotic Violations',
            'Crime Name3': ('3584', 'DRUG/NARCOTIC VIOLATIONS')  # Tuple for specific Offence Code
        }
    }

    # Apply the updates
    for nibrs_code, names in updates.items():
        for column, value in names.items():
            if isinstance(value, tuple):
                offence_code, crime_name = value
                df.loc[(df['NIBRS Code'] == nibrs_code) & (df['Offence Code'] == offence_code), column] = crime_name.upper()
            else:
                df.loc[df['NIBRS Code'] == nibrs_code, column] = value

    # Define the condition for dropping rows
    condition = (df['NIBRS Code'] == '90Z') & \
                (df['Crime Name1'].isna() | df['Crime Name1'].str.strip().eq('')) & \
                (df['Crime Name2'].isna() | df['Crime Name2'].str.strip().eq('')) & \
                (df['Crime Name3'].isna() | df['Crime Name3'].str.strip().eq(''))

    # Drop rows that meet the condition and return the updated DataFrame
    return df[~condition]

# Apply the function to the DataFrame
df_loc = update_and_clean_crime_data(df_loc)

# %%
# Calculate the overall mode for 'City'
overall_mode = df_loc['City'].mode().iloc[0] if not df_loc['City'].mode().empty else None

# Group by 'Location', and calculate the mode of 'City' for each group
mode_per_category = df_loc.groupby(['Location','Street Name','Zip Code'])['City'].agg(lambda x: x.mode().iloc[0] if not x.mode().empty else overall_mode)

# Create a new column for the mapped modes
df_loc['Mapped Mode'] = df_loc.set_index(['Location','Street Name','Zip Code']).index.map(mode_per_category)

# Fill missing values in 'City' using the mapped modes
df_loc['City'].fillna(df_loc['Mapped Mode'], inplace=True)

# Drop the auxiliary column 'Mapped Mode'
df_loc.drop(columns=['Mapped Mode'], inplace=True)

# %%
# Convert the 'Police District Number' column to string
df_loc['Police District Number'] = df_loc['Police District Number'].astype(str)

# Replace '.0' with an empty string
df_loc['Police District Number'] = df_loc['Police District Number'].str.replace('.0', '')

# Calculate the overall mode for 'Police District Name'
overall_mode = df_loc['Police District Name'].mode().iloc[0] if not df_loc['Police District Name'].mode().empty else None

# Group by 'Location' and 'City', and calculate the mode of 'Police District Name' for each group
mode_per_category = df_loc.groupby(['Location','Police District Number','Street Name','City'])['Police District Name'].agg(lambda x: x.mode().iloc[0] if not x.mode().empty else overall_mode)

# Create a new column for the mapped modes
df_loc['Mapped Mode'] = df_loc.set_index(['Location','Police District Number','Street Name','City']).index.map(mode_per_category)

# Fill missing values in 'Police District Name' using the mapped modes
df_loc['Police District Name'].fillna(df_loc['Mapped Mode'], inplace=True)

# Drop the auxiliary column 'Mapped Mode'
df_loc.drop(columns=['Mapped Mode'], inplace=True)

# %%
df_loc['State'].value_counts()
# Out:
# State
# MD    409827
# 16       210
# DC         9
# ME         2
# MS         2
# 0          1
# MC         1
# 17         1
# ND         1
# 15         1
# Name: count, dtype: int64

# %%
df_loc['State'] = df_loc['State'].apply(lambda x: 'MD' if x != 'MD' else x)
